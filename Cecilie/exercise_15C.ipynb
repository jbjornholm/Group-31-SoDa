# %% [markdown]
# # Exercise Set 15: Text Classification and Sentiment Analysis
#
# *Morning, August 21, 2019*
#
# In this Exercise Set you will practice using two basic text classification methods: rule- and machine learning-based. The exercise has XX parts:
#
# 1. Implement a lexical look-up method.
# 2. Apply pre-packaged rulebased dictionaries.
# 3. Train a simple baseline machine learning classifier.
#
# In the end, you will then compare the results of these approaches.
#
# First, load our standard stuff and import the following modules:

# %%
## Standard stuff:
import numpy as np, seaborn as sns, pandas as pd
## For text classification:
import nltk, nltk.sentiment, sklearn
# %matplotlib inline

# %% [markdown]
# ## Exercise 15 Part 1: Implementing your own Lexical Lookup method
# There are many curated dictionaries and lexicons online for all sorts of topics (see for instance this project: https://hedonometer.org/index.html where the lexicons behind it can be downloaded here: https://github.com/andyreagan/hedonometer/blob/master/hedonometer/static/hedonometer/labMT1.txt). For this exercise we will use the following list of positive and negative words (positive:http://ptrckprry.com/course/ssd/data/negative-words.txt ; negative: http://ptrckprry.com/course/ssd/data/positive-words.txt) compilled by Hu and Liu.
#
# We will use the following dataset (a random sample of the trustpilot review data we collected in exercise 8) to practice on.
#
# > **Ex. 15.1.1:**  Load it like this (remember to import the `request` package):
#
# ```python
# # download data
# path2data = 'https://raw.githubusercontent.com/snorreralund/scraping_seminar/master/english_review_sample.csv'
# df = pd.read_csv(path2data)```
#
# The important columns are ***reviewBody*** containing the text, and the ***reviewRating_ratingValue*** containing the rating / stars.

# %%
# [Answer to Ex. 15.1.1]
import requests

path2data = 'https://raw.githubusercontent.com/snorreralund/scraping_seminar/master/english_review_sample.csv'
df = pd.read_csv(path2data)
# Out:
#       Unnamed: 0                                         __domain__  \
# 0         159770        https://trustpilot.com/review/www.exmed.net
# 1         168724      https://trustpilot.com/review/mapscompany.com
# 2          96443  https://trustpilot.com/review/www.thriftbooks.com
# 3         173433        https://trustpilot.com/review/fabletics.com
# 4         138968   https://trustpilot.com/review/www.enterprise.com
# 5          67290      https://trustpilot.com/review/newyorkpass.com
# 6          31913   https://trustpilot.com/review/www.comfysacks.com
# 7          40227    https://trustpilot.com/review/www.priceline.com
# 8         150471      https://trustpilot.com/review/mycomicshop.com
# 9         180105   https://trustpilot.com/review/www.shoedazzle.com
# 10           907      https://trustpilot.com/review/1800dentist.com
# 11         28064  https://trustpilot.com/review/www.pureformulas...
# 12         83452  https://trustpilot.com/review/www.allianztrave...
# 13         53981    https://trustpilot.com/review/vacuum-direct.com
# 14        126297         https://trustpilot.com/review/www.lang.com
# 15         98671   https://trustpilot.com/review/shipacardirect.com
# 16         49921  https://trustpilot.com/review/www.compliancesi...
# 17         36838   https://trustpilot.com/review/www.galahotels.com
# 18         15109   https://trustpilot.com/review/www.cashnetusa.com
# 19        107565  https://trustpilot.com/review/www.textbookrush...
# 20         35809       https://trustpilot.com/review/hellofresh.com
# 21         45903        https://trustpilot.com/review/www.amoma.com
# 22         36653      https://trustpilot.com/review/plaquemaker.com
# 23         96444  https://trustpilot.com/review/www.thriftbooks.com
# 24         66356  https://trustpilot.com/review/privateinterneta...
# 25          5417  https://trustpilot.com/review/www.textbookrush...
# 26        129783     https://trustpilot.com/review/www.airsplat.com
# 27        112494      https://trustpilot.com/review/plaquemaker.com
# 28         13623       https://trustpilot.com/review/careington.com
# 29         65407    https://trustpilot.com/review/www.cafepress.com
# ...          ...                                                ...
# 9970       58842    https://trustpilot.com/review/www.cafepress.com
# 9971      111968   https://trustpilot.com/review/thelogocompany.net
# 9972       75459  https://trustpilot.com/review/catholiccompany.com
# 9973      140752          https://trustpilot.com/review/tradesy.com
# 9974      135153        https://trustpilot.com/review/golfclubs.com
# 9975      138497  https://trustpilot.com/review/mysterytacklebox...
# 9976       46453       https://trustpilot.com/review/hellofresh.com
# 9977       28698  https://trustpilot.com/review/techliveconnect.com
# 9978      141414          https://trustpilot.com/review/justfly.com
# 9979      125471   https://trustpilot.com/review/www.bookrenter.com
# 9980       50299  https://trustpilot.com/review/www.oktoberfesth...
# 9981      163976   https://trustpilot.com/review/www.timberland.com
# 9982      136532    https://trustpilot.com/review/www.partsgeek.com
# 9983       24347        https://trustpilot.com/review/www.reeds.com
# 9984      113836          https://trustpilot.com/review/justfly.com
# 9985      176062    https://trustpilot.com/review/www.partsgeek.com
# 9986       43073   https://trustpilot.com/review/airparkparking.com
# 9987       63520         https://trustpilot.com/review/www.xoom.com
# 9988      175268      https://trustpilot.com/review/greenvelope.com
# 9989      145374   https://trustpilot.com/review/www.cartrawler.com
# 9990       91617    https://trustpilot.com/review/www.cafepress.com
# 9991       19692    https://trustpilot.com/review/www.cafepress.com
# 9992      140837            https://trustpilot.com/review/dial7.com
# 9993      113870  https://trustpilot.com/review/www.mileskimball...
# 9994       62697  https://trustpilot.com/review/www.textbookrush...
# 9995       89738  https://trustpilot.com/review/www.pureformulas...
# 9996      118726      https://trustpilot.com/review/impactsigns.com
# 9997       60622              https://trustpilot.com/review/nfm.com
# 9998       94658  https://trustpilot.com/review/www.airportparki...
# 9999      165552   https://trustpilot.com/review/www.creditloan.com
#
#       address_@type address_addressCountry  address_addressLocality  \
# 0     PostalAddress                    NaN                   Fenton
# 1     PostalAddress                    NaN         Petit-Rocher, NB
# 2     PostalAddress                    NaN                  Tukwila
# 3     PostalAddress                    NaN                      NaN
# 4     PostalAddress                     US                 St Louis
# 5     PostalAddress                    NaN            New York City
# 6     PostalAddress                     US              Saint Louis
# 7     PostalAddress                     US                      NaN
# 8     PostalAddress                    NaN                Arlington
# 9     PostalAddress                     US                      NaN
# 10    PostalAddress                    NaN              Los Angeles
# 11    PostalAddress                    NaN                   Medley
# 12    PostalAddress                    NaN                 Richmond
# 13    PostalAddress                     US                  Bad Axe
# 14    PostalAddress                    NaN                 Waukesha
# 15    PostalAddress                    NaN                      NaN
# 16    PostalAddress                    NaN             Chadwick, IL
# 17    PostalAddress                    NaN  Mecidiyekoy / Istanbul
# 18    PostalAddress                    NaN              Chicago, IL
# 19    PostalAddress                    NaN                      NaN
# 20    PostalAddress                    NaN                      NaN
# 21    PostalAddress                     US                   Genève
# 22    PostalAddress                    NaN                Fortville
# 23    PostalAddress                    NaN                  Tukwila
# 24    PostalAddress                    NaN                      NaN
# 25    PostalAddress                    NaN                      NaN
# 26    PostalAddress                    NaN                      NaN
# 27    PostalAddress                    NaN                Fortville
# 28    PostalAddress                    NaN                   Frisco
# 29    PostalAddress                    NaN                      NaN
# ...             ...                    ...                      ...
# 9970  PostalAddress                    NaN                      NaN
# 9971  PostalAddress                    NaN                 New York
# 9972  PostalAddress                    NaN                Charlotte
# 9973  PostalAddress                    NaN   Santa Monica, CA 90401
# 9974  PostalAddress                     US                 Portland
# 9975  PostalAddress                    NaN                      NaN
# 9976  PostalAddress                    NaN                      NaN
# 9977  PostalAddress                     US                      NaN
# 9978  PostalAddress                    NaN                      NaN
# 9979  PostalAddress                    NaN                San Mateo
# 9980  PostalAddress                    NaN                Roseville
# 9981  PostalAddress                    NaN                      NaN
# 9982  PostalAddress                    NaN                  Marlton
# 9983  PostalAddress                    NaN               Wilmington
# 9984  PostalAddress                    NaN                      NaN
# 9985  PostalAddress                    NaN                  Marlton
# 9986  PostalAddress                     US                  Jamaica
# 9987  PostalAddress                    NaN            San Francisco
# 9988  PostalAddress                    NaN                  Seattle
# 9989  PostalAddress                     IE                  Dublin
# 9990  PostalAddress                    NaN                      NaN
# 9991  PostalAddress                    NaN                      NaN
# 9992  PostalAddress                    NaN     Long Island City, NY
# 9993  PostalAddress                     US                  Oshkosh
# 9994  PostalAddress                    NaN                      NaN
# 9995  PostalAddress                    NaN                   Medley
# 9996  PostalAddress                    NaN                 LaGrange
# 9997  PostalAddress                    NaN                    Omaha
# 9998  PostalAddress                    NaN             Santa Monica
# 9999  PostalAddress                     US                    Tampa
#
#      address_postalCode                              address_streetAddress  \
# 0                 63026                                   218 Seebold Spur
# 1               E8J 1E4                                  713 rue de la Mer
# 2                 98188                       18300 Cascade Ave S, Ste 150
# 3                   NaN                                                NaN
# 4                 63105                              600 Corporate Park Dr
# 5              NY 10036                               36 West 44th Street
# 6                 63114                  1976 Innerbelt Business Center Dr
# 7                   NaN                                                NaN
# 8                 76010                                1800 Timberlake Dr.
# 9                   NaN                                                NaN
# 10                90045                                  6060 Center Drive
# 11                33178                          11800 NW 102 Road Suite 2
# 12                23233                                 9950 Mayland Drive
# 13                48413                                      980 Ubly Road
# 14                53187                                        PO Box 1605
# 15                  NaN                                                NaN
# 16                61014                               56 South Main Street
# 17             TR 34394  Gulbahar Mh. Harmanyolu Ust Sk. Meric Plaza No...
# 18                60604                                   175 West Jackson
# 19                  NaN                                                NaN
# 20                  NaN                                                NaN
# 21                 1201                                     Quai Wilson 45
# 22                46040                            289 Business Park Drive
# 23                98188                       18300 Cascade Ave S, Ste 150
# 24                  NaN                                                NaN
# 25                  NaN                                                NaN
# 26                  NaN                                                NaN
# 27                46040                            289 Business Park Drive
# 28                75034                               7400 Gaylord Parkway
# 29                  NaN                                                NaN
# ...                 ...                                                ...
# 9970                NaN                                                NaN
# 9971              10036             1180 Avenue of the Americas- 8th Floor
# 9972              28273                            615 E Westinghouse Blvd
# 9973                NaN                         1217 2nd Street, 4th Floor
# 9974                NaN                                                NaN
# 9975                NaN                                                NaN
# 9976                NaN                                                NaN
# 9977                NaN                                                NaN
# 9978                NaN                                                NaN
# 9979              94403                         1200 Park Place, Suite 250
# 9980              55113                                2001 County Rd C2 W
# 9981                NaN                                                NaN
# 9982              08053                      777 Route 70 East Suite G-103
# 9983              28402                                        PO Box 2229
# 9984                NaN                                                NaN
# 9985              08053                      777 Route 70 East Suite G-103
# 9986              11434                           153-44 South Conduit Ave
# 9987              94105                                         425 Market
# 9988              98101                         1620 4th Avenue, Suite 200
# 9989                NaN    Classon House, Dundrum Business Park, Dublin 14
# 9990                NaN                                                NaN
# 9991                NaN                                                NaN
# 9992              11101                                  43-23 35th Street
# 9993              54906                                    250 City Center
# 9994                NaN                                                NaN
# 9995              33178                          11800 NW 102 Road Suite 2
# 9996              60525                                26 E Burlington Ave
# 9997              68114                                      700 S 72nd ST
# 9998              90401                          1640 5th Street Suite 202
# 9999              33607                2202 N. West Shore Blvd., Suite 200
#
#      author_@type         datePublished  \
# 0          Person  2017-07-29T20:27:03Z
# 1          Person  2017-08-11T20:09:48Z
# 2          Person  2015-03-19T22:59:22Z
# 3          Person  2017-04-30T19:47:39Z
# 4          Person  2018-05-26T20:43:41Z
# 5          Person  2017-04-21T16:07:53Z
# 6          Person  2014-03-03T22:40:21Z
# 7          Person  2014-12-30T15:06:07Z
# 8          Person  2015-12-09T22:39:48Z
# 9          Person  2015-11-10T17:41:44Z
# 10         Person  2017-06-12T14:20:34Z
# 11         Person  2013-08-01T12:22:36Z
# 12         Person  2015-08-17T16:54:09Z
# 13         Person  2017-01-23T22:40:19Z
# 14         Person  2017-01-03T17:18:09Z
# 15         Person  2014-04-23T16:45:53Z
# 16         Person  2015-03-12T21:09:52Z
# 17         Person  2017-06-23T09:48:35Z
# 18         Person  2017-11-14T18:41:13Z
# 19         Person  2015-02-10T20:24:17Z
# 20         Person  2018-03-06T20:47:10Z
# 21         Person  2017-03-22T19:42:16Z
# 22         Person  2014-01-10T22:04:27Z
# 23         Person  2015-03-19T22:38:24Z
# 24         Person  2016-03-15T23:48:30Z
# 25         Person  2017-12-08T23:12:17Z
# 26         Person  2016-09-08T01:28:32Z
# 27         Person  2016-03-09T22:30:40Z
# 28         Person  2017-08-29T20:15:17Z
# 29         Person  2016-12-19T12:19:24Z
# ...           ...                   ...
# 9970       Person  2018-05-30T19:31:44Z
# 9971       Person  2016-02-01T01:53:41Z
# 9972       Person  2017-10-30T15:01:08Z
# 9973       Person  2017-06-06T22:12:21Z
# 9974       Person  2015-02-09T00:50:22Z
# 9975       Person  2014-09-03T17:47:23Z
# 9976       Person  2017-05-18T21:59:58Z
# 9977       Person  2017-12-06T22:41:02Z
# 9978       Person  2016-06-04T17:54:51Z
# 9979       Person  2014-11-08T21:11:05Z
# 9980       Person  2014-10-30T13:42:30Z
# 9981       Person  2017-08-08T02:54:54Z
# 9982       Person  2014-08-10T15:51:03Z
# 9983       Person  2015-06-07T12:15:13Z
# 9984       Person  2016-10-05T18:29:44Z
# 9985       Person  2015-05-14T16:26:34Z
# 9986       Person  2017-05-16T01:26:02Z
# 9987       Person  2018-08-10T00:02:40Z
# 9988       Person  2017-05-10T17:51:49Z
# 9989       Person  2017-07-26T18:11:14Z
# 9990       Person  2015-07-14T10:15:06Z
# 9991       Person  2014-09-22T19:26:27Z
# 9992       Person  2016-01-13T05:01:02Z
# 9993       Person  2017-12-19T01:21:44Z
# 9994       Person  2016-12-17T01:04:37Z
# 9995       Person  2013-07-28T14:55:42Z
# 9996       Person  2017-09-25T20:59:10Z
# 9997       Person  2018-07-31T00:58:41Z
# 9998       Person  2018-07-21T01:17:08Z
# 9999       Person  2014-02-08T00:48:56Z
#
#                                        email  ... inLanguage  \
# 0                            sales@exmed.net  ...         en
# 1                    contact@mapscompany.com  ...         en
# 2                    reviews@thriftbooks.com  ...         en
# 3                                        NaN  ...         en
# 4                                        NaN  ...         en
# 5                       info@newyorkpass.com  ...         en
# 6                        Info@ComfySacks.com  ...         en
# 7                                        NaN  ...         en
# 8                    service@mycomicshop.com  ...         en
# 9                                        NaN  ...         en
# 10                  feedback@1800dentist.com  ...         en
# 11                     help@pureformulas.com  ...         en
# 12           help.team@allianzassistance.com  ...         en
# 13                   sales@vacuum-direct.com  ...         en
# 14                          service@lang.com  ...         en
# 15                                       NaN  ...         en
# 16                 Sales@compliancesigns.com  ...         en
# 17                       info@galahotels.com  ...         en
# 18                    support@cashnetusa.com  ...         en
# 19                     help@textbookrush.com  ...         en
# 20                      hello@hellofresh.com  ...         en
# 21                         support@amoma.com  ...         en
# 22                      help@plaquemaker.com  ...         en
# 23                   reviews@thriftbooks.com  ...         en
# 24         support@privateinternetaccess.com  ...         en
# 25                     help@textbookrush.com  ...         en
# 26                                       NaN  ...         en
# 27                      help@plaquemaker.com  ...         en
# 28                       info@careington.com  ...         en
# 29                      social@cafepress.com  ...         en
# ...                                      ...  ...        ...
# 9970                    social@cafepress.com  ...         en
# 9971             logosale@thelogocompany.net  ...         en
# 9972     customerservice@catholiccompany.com  ...         en
# 9973                        team@tradesy.com  ...         en
# 9974               sales@golfclubsdirect.com  ...         en
# 9975            support@mysterytacklebox.com  ...         en
# 9976                    hello@hellofresh.com  ...         en
# 9977             support@techliveconnect.com  ...         en
# 9978                      Social@justfly.com  ...         en
# 9979                     info@bookrenter.com  ...         en
# 9980                info@oktoberfesthaus.com  ...         en
# 9981                                     NaN  ...         en
# 9982                                     NaN  ...         en
# 9983                        orders@reeds.com  ...         en
# 9984                      Social@justfly.com  ...         en
# 9985                                     NaN  ...         en
# 9986                 info@airparkparking.com  ...         en
# 9987           customersatisfaction@xoom.com  ...         en
# 9988                    info@greenvelope.com  ...         en
# 9989                    hello@cartrawler.com  ...         en
# 9990                    social@cafepress.com  ...         en
# 9991                    social@cafepress.com  ...         en
# 9992                            cs@dial7.com  ...         en
# 9993                    CSR@MilesKimball.com  ...         en
# 9994                   help@textbookrush.com  ...         en
# 9995                   help@pureformulas.com  ...         en
# 9996                 shabbir@impactsigns.com  ...         en
# 9997                                     NaN  ...         en
# 9998  service@airportparkingreservations.com  ...         en
# 9999                 feedback@creditloan.com  ...         en
#
#      itemReviewed_@type               itemReviewed_name     meta_@type  \
# 0                 Thing          Express Medical Supply  LocalBusiness
# 1                 Thing                     MapsCompany  LocalBusiness
# 2                 Thing                    Thrift Books  LocalBusiness
# 3                 Thing                       Fabletics  LocalBusiness
# 4                 Thing                      Enterprise  LocalBusiness
# 5                 Thing                   New York Pass  LocalBusiness
# 6                 Thing                     Comfy Sacks  LocalBusiness
# 7                 Thing                       Priceline  LocalBusiness
# 8                 Thing                     MyComicShop  LocalBusiness
# 9                 Thing                      ShoeDazzle  LocalBusiness
# 10                Thing                   1-800-DENTIST  LocalBusiness
# 11                Thing                    PureFormulas  LocalBusiness
# 12                Thing       Allianz Global Assistance  LocalBusiness
# 13                Thing                VacuumDirect.com  LocalBusiness
# 14                Thing                            LANG  LocalBusiness
# 15                Thing               Ship A Car Direct  LocalBusiness
# 16                Thing                 ComplianceSigns  LocalBusiness
# 17                Thing                  GalaHotels.com  LocalBusiness
# 18                Thing                      CashNetUSA  LocalBusiness
# 19                Thing                    TextbookRush  LocalBusiness
# 20                Thing                   HelloFresh US  LocalBusiness
# 21                Thing                       AMOMA.com  LocalBusiness
# 22                Thing                     PlaqueMaker  LocalBusiness
# 23                Thing                    Thrift Books  LocalBusiness
# 24                Thing         Private Internet Access  LocalBusiness
# 25                Thing                    TextbookRush  LocalBusiness
# 26                Thing                        Airsplat  LocalBusiness
# 27                Thing                     PlaqueMaker  LocalBusiness
# 28                Thing                      Careington  LocalBusiness
# 29                Thing                       CafePress  LocalBusiness
# ...                 ...                             ...            ...
# 9970              Thing                       CafePress  LocalBusiness
# 9971              Thing                The Logo Company  LocalBusiness
# 9972              Thing            The Catholic Company  LocalBusiness
# 9973              Thing                         Tradesy  LocalBusiness
# 9974              Thing             GolfClubsDirect.com  LocalBusiness
# 9975              Thing              Mystery Tackle Box  LocalBusiness
# 9976              Thing                   HelloFresh US  LocalBusiness
# 9977              Thing               Tech Live Connect  LocalBusiness
# 9978              Thing                         JustFly  LocalBusiness
# 9979              Thing                      BookRenter  LocalBusiness
# 9980              Thing                Oktoberfest Haus  LocalBusiness
# 9981              Thing                      Timberland  LocalBusiness
# 9982              Thing                      Parts Geek  LocalBusiness
# 9983              Thing                  Reeds Jewelers  LocalBusiness
# 9984              Thing                         JustFly  LocalBusiness
# 9985              Thing                      Parts Geek  LocalBusiness
# 9986              Thing                  Airparkparking  LocalBusiness
# 9987              Thing      Xoom Global Money Transfer  LocalBusiness
# 9988              Thing                 Greenvelope.com  LocalBusiness
# 9989              Thing                      CarTrawler  LocalBusiness
# 9990              Thing                       CafePress  LocalBusiness
# 9991              Thing                       CafePress  LocalBusiness
# 9992              Thing  Dial 7 Car & Limousine Service  LocalBusiness
# 9993              Thing                   Miles Kimball  LocalBusiness
# 9994              Thing                    TextbookRush  LocalBusiness
# 9995              Thing                    PureFormulas  LocalBusiness
# 9996              Thing          Impact Corporate Signs  LocalBusiness
# 9997              Thing         Nebraska Furniture Mart  LocalBusiness
# 9998              Thing  AirportParkingReservations.com  LocalBusiness
# 9999              Thing                  CreditLoan.com  LocalBusiness
#
#                                 name  \
# 0             Express Medical Supply
# 1                        MapsCompany
# 2                       Thrift Books
# 3                          Fabletics
# 4                         Enterprise
# 5                      New York Pass
# 6                        Comfy Sacks
# 7                          Priceline
# 8                        MyComicShop
# 9                         ShoeDazzle
# 10                     1-800-DENTIST
# 11                      PureFormulas
# 12         Allianz Global Assistance
# 13                  VacuumDirect.com
# 14                              LANG
# 15                 Ship A Car Direct
# 16                   ComplianceSigns
# 17                    GalaHotels.com
# 18                        CashNetUSA
# 19                      TextbookRush
# 20                     HelloFresh US
# 21                         AMOMA.com
# 22                       PlaqueMaker
# 23                      Thrift Books
# 24           Private Internet Access
# 25                      TextbookRush
# 26                          Airsplat
# 27                       PlaqueMaker
# 28                        Careington
# 29                         CafePress
# ...                              ...
# 9970                       CafePress
# 9971                The Logo Company
# 9972            The Catholic Company
# 9973                         Tradesy
# 9974             GolfClubsDirect.com
# 9975              Mystery Tackle Box
# 9976                   HelloFresh US
# 9977               Tech Live Connect
# 9978                         JustFly
# 9979                      BookRenter
# 9980                Oktoberfest Haus
# 9981                      Timberland
# 9982                      Parts Geek
# 9983                  Reeds Jewelers
# 9984                         JustFly
# 9985                      Parts Geek
# 9986                  Airparkparking
# 9987      Xoom Global Money Transfer
# 9988                 Greenvelope.com
# 9989                      CarTrawler
# 9990                       CafePress
# 9991                       CafePress
# 9992  Dial 7 Car & Limousine Service
# 9993                   Miles Kimball
# 9994                    TextbookRush
# 9995                    PureFormulas
# 9996          Impact Corporate Signs
# 9997         Nebraska Furniture Mart
# 9998  AirportParkingReservations.com
# 9999                  CreditLoan.com
#
#                                              reviewBody reviewRating_@type  \
# 0     Lots of inventory, very fast and efficient. I ...             Rating
# 1     I did not received the map I had ordered and p...             Rating
# 2     After searching a number of stores here in my ...             Rating
# 3     Website is not intuitive.  I don't like having...             Rating
# 4     Outstanding customer service, appreciated the ...             Rating
# 5     Waiting in line to get on the Big Bus...at all...             Rating
# 6     I've been to the 'other' sac store in the Mall...             Rating
# 7     I don't even bother making hotel reservations ...             Rating
# 8                                       Great packaging             Rating
# 9           They hurt like crazy .. not worth the money             Rating
# 10    We were told the dentist could\nDo sedation th...             Rating
# 11                                Very Good Company :-)             Rating
# 12    Helpful, friendly and didn't give me any probl...             Rating
# 13    Delivered very quickly and exactly what I need...             Rating
# 14    Very nice calendars, cards, and stationary I h...             Rating
# 15    I had to move my car from Dublin, Ohio to Dall...             Rating
# 16    the signs were made very well , very pleased w...             Rating
# 17    One night in Future Inn Cardiff Bay, got a roo...             Rating
# 18                                 Helpful and curtious             Rating
# 19    I received my book in the mannor in which they...             Rating
# 20    I love the freshness of the ingredients, the e...             Rating
# 21    Perfect winding up, so the travelling gives pl...             Rating
# 22    I actually called a friend today to direct the...             Rating
# 23    The three books I ordered came in a timely fas...             Rating
# 24             Fully secure. What more can you ask for?             Rating
# 25    Your prices are competitive and your checks co...             Rating
# 26    Ordered a tactical vest. Had a question after ...             Rating
# 27    Ordered a plaque for our marketer of the month...             Rating
# 28              Very easy to sign up and great savings.             Rating
# 29    Happy with product, came in timely manner, pac...             Rating
# ...                                                 ...                ...
# 9970  Bags came in looking great - just wished the i...             Rating
# 9971  The first round of proofs were delivered and w...             Rating
# 9972  Shipped in a timely manner - even followed up ...             Rating
# 9973  United States\n\n \n\nI had a sale for my Loui...             Rating
# 9974  As advertised, delivered very quickly, all was...             Rating
# 9975  Definitely a value, and I get to try the newes...             Rating
# 9976  We love hello fresh! It's packaged wonderfully...             Rating
# 9977  alls very good at fixing everything .nice and ...             Rating
# 9978       Easy to use website with competitive prices.             Rating
# 9979              Arrived later than what was expected.             Rating
# 9980  Only thing that bothered me was I didn't revie...             Rating
# 9981  Order arrived in a damaged package. Trousers i...             Rating
# 9982  Hi Everyone,\r\nI need a car part,  a very exp...             Rating
# 9983  I purchased an Alex and Ani bracelet, one of w...             Rating
# 9984                      it was more fast to find fly.             Rating
# 9985  I went to a local store to purchase a bug defl...             Rating
# 9986  I called as I was told to, after I picked up m...             Rating
# 9987  Excellent way to transfer money home and at a ...             Rating
# 9988  I wish there was a couple more functionalities...             Rating
# 9989                              Excellent al the way.             Rating
# 9990  Looking for cards with LEMONS - I founds an ov...             Rating
# 9991  I was thrilled to find a calendar about a plac...             Rating
# 9992  The driver arrived ten minutes early. He was p...             Rating
# 9993  Everything went very well with the ordering pr...             Rating
# 9994  The only issues I have is when buying from 3rd...             Rating
# 9995  Wide range of products.  Always have found wha...             Rating
# 9996  If I could leave no stars, I would. I left an ...             Rating
# 9997  Everything was quick and easy, did not have al...             Rating
# 9998  For us the best place to leave car. From the w...             Rating
# 9999  If you're looking for an informative website o...             Rating
#
#      reviewRating_ratingValue  \
# 0                           5
# 1                           3
# 2                           5
# 3                           2
# 4                           5
# 5                           4
# 6                           5
# 7                           5
# 8                           5
# 9                           2
# 10                          2
# 11                          5
# 12                          5
# 13                          5
# 14                          5
# 15                          5
# 16                          5
# 17                          4
# 18                          5
# 19                          5
# 20                          5
# 21                          5
# 22                          5
# 23                          5
# 24                          5
# 25                          5
# 26                          5
# 27                          5
# 28                          5
# 29                          5
# ...                       ...
# 9970                        4
# 9971                        5
# 9972                        5
# 9973                        1
# 9974                        5
# 9975                        5
# 9976                        5
# 9977                        5
# 9978                        5
# 9979                        3
# 9980                        5
# 9981                        1
# 9982                        5
# 9983                        5
# 9984                        5
# 9985                        5
# 9986                        5
# 9987                        5
# 9988                        3
# 9989                        5
# 9990                        4
# 9991                        3
# 9992                        5
# 9993                        5
# 9994                        4
# 9995                        4
# 9996                        1
# 9997                        4
# 9998                        5
# 9999                        5
#
#                                               telephone  \
# 0                                        (800) 633-2139
# 1                                                   NaN
# 2                                          253-275-2251
# 3                                          855-202-3570
# 4                                                   NaN
# 5                                      1 (877) 714-1999
# 6                                            8778843826
# 7                                                   NaN
# 8                                          817-860-7827
# 9                                          888.508.1888
# 10                                         310-215-6400
# 11                                       1-800-383-6008
# 12                                       1-866-884-3556
# 13                                       1-866-927-4327
# 14                                       1-800-967-3399
# 15                                                  NaN
# 16                                       1-800-578-1245
# 17                                   0044 20 3384 64 48
# 18                                         888.801.9075
# 19                                       (614) 729-2477
# 20                                         646-846-3663
# 21                                         +41225182013
# 22                                       1-866-880-9617
# 23                                         253-275-2251
# 24                                                  NaN
# 25                                       (614) 729-2477
# 26                                                  NaN
# 27                                       1-866-880-9617
# 28                                       (800) 290-0523
# 29                                       1-877-809-1659
# ...                                                 ...
# 9970                                     1-877-809-1659
# 9971                                       212-382-4644
# 9972                                       866-522-8465
# 9973  +1-310-912-7966                               ...
# 9974                                       800-391-9332
# 9975                                                NaN
# 9976                                       646-846-3663
# 9977                                                NaN
# 9978                                     1-800-717-5015
# 9979                                                NaN
# 9980                                     (877) 577-2801
# 9981                                                NaN
# 9982                                                NaN
# 9983                                       877-406-3266
# 9984                                     1-800-717-5015
# 9985                                                NaN
# 9986                                       718-276-7000
# 9987                                     (877) 815-1531
# 9988                                       888-505-2588
# 9989                                                NaN
# 9990                                     1-877-809-1659
# 9991                                     1-877-809-1659
# 9992                                       212-777-7777
# 9993                                       855-202-7394
# 9994                                     (614) 729-2477
# 9995                                     1-800-383-6008
# 9996                                       708-469-7178
# 9997                                       800-336-9136
# 9998                                                NaN
# 9999                                         8135270728
#
#                          categories
# 0                 /health_wellbeing
# 1                  /travel_holidays
# 2                    /entertainment
# 3                  /clothes_fashion
# 4                   /transportation
# 5                  /travel_holidays
# 6                      /home_garden
# 7                  /travel_holidays
# 8                    /entertainment
# 9                  /clothes_fashion
# 10                /health_wellbeing
# 11                /health_wellbeing
# 12          /money,/travel_holidays
# 13                     /home_garden
# 14                             /art
# 15                  /transportation
# 16                  /art,/companies
# 17                 /travel_holidays
# 18                           /money
# 19                   /entertainment
# 20                   /food_beverage
# 21                 /travel_holidays
# 22                             /art
# 23                   /entertainment
# 24                        /computer
# 25                   /entertainment
# 26                         /leisure
# 27                             /art
# 28                /health_wellbeing
# 29                 /clothes_fashion
# ...                             ...
# 9970               /clothes_fashion
# 9971                /art,/companies
# 9972               /clothes_fashion
# 9973               /clothes_fashion
# 9974                         /sport
# 9975                       /leisure
# 9976                 /food_beverage
# 9977                     /companies
# 9978               /travel_holidays
# 9979               /public_services
# 9980  /clothes_fashion,/home_garden
# 9981               /clothes_fashion
# 9982                /transportation
# 9983               /clothes_fashion
# 9984               /travel_holidays
# 9985                /transportation
# 9986               /travel_holidays
# 9987                         /money
# 9988                 /entertainment
# 9989                /transportation
# 9990               /clothes_fashion
# 9991               /clothes_fashion
# 9992                /transportation
# 9993                   /home_garden
# 9994                 /entertainment
# 9995              /health_wellbeing
# 9996                     /companies
# 9997      /electronics,/home_garden
# 9998               /travel_holidays
# 9999                         /money
#
# [10000 rows x 21 columns]

# %% [markdown]
# > **Ex. 15.1.2:** Next, we should download and prepare the dictionaries.
# 1. Download the lists using python's `requests.get()`. The lists are documents of words separated by new line (which is the '\n' character).
# 2. Make sure to remove the comment section in the top by splitting at the right place.
# 3. `.split()` these documents into words.
# 4. Convert them into sets (using the `set()`-command) and assign these to two variables (e.g. ***positive*** and ***negative***).
#
# *Hint*: You can do all of the above in one line of code per list.

# %%
# [Answer to Ex. 15.1.2]
url_neg = 'http://ptrckprry.com/course/ssd/data/negative-words.txt'
url_pos = 'http://ptrckprry.com/course/ssd/data/positive-words.txt'

# %%
import scraping_class
logfile = 'log.txt' ## name your log file.
connector = scraping_class.Connector(logfile)

# %%
response_pos,callidp = connector.get(url_pos,'positive')
response_neg,callidn = connector.get(url_neg,'negative')

# %%
positive = set(response_pos.text.split('\n')[35:])
negative = set(response_neg.text.split('\n')[35:])

# %% [markdown]
# Now we need to prepare the trustpilot reviews, our documents to be analyzed. This means lowercasing and tokenizing them to match the format that our dictionary comes in.
#
# > **Ex. 15.1.3:** Define a function `preprocessing(string)`, that takes in a string and returns a list of words. The function should do the following:
# 1. lowercases the string using the `.lower()` command.
# 2. tokenize the words using the `nltk.tokenize.TweetTokenizer()` which is good for social media type user content (i.e. emojiies and more free use of punctuation and commas.
# 3. return tokenized documents.
#
# *Hint*: You can first initialize the tokenizer (outside the preprocessing function), and then you use the `.tokenize()` method.

# %%
# [Answer to Ex 15.1.3]
tweet_tokenizer = nltk.tokenize.casual.TweetTokenizer()

def preprocessing(string):
    output = string.lower()
    output2 = tweet_tokenizer.tokenize(output)
    return output2

preprocessing('How are you ;)')
# Out:
# ['how', 'are', 'you', ';)']

# %% [markdown]
# >**Ex 15.1.4:** Apply the preprocessing function to all the documents (i.e. our review texts in the column ***reviewBody***).
#
# *Hint:* Use the `.apply()` method.

# %%
# [Answer to Ex 15.1.4]
reviews = df['reviewBody'].apply(preprocessing)

# %% [markdown]
# Now, we need to match the words in our dictionaries to the tokenized documents.
# >**Ex 15.1.5:** Define a function `count_dictionary(document,dictionary)` that takes a tokenized document and a set of words (i.e. the dictionaries we loaded in Ex 15.1.2) and counts the number of matches. The function should do the following:
# 1. Filter the words not in the dictionary.
# *Hint*: you can use a list comprehension or for loop and `if word in` condition.
# 2. Return the length of the filtered document.

# %%
# [Answer Ex 15.1.5]

#Metode 2
def count_dictionary(document, dictionary):
    filtered = [ x for x in document if x in dictionary]
    return len(filtered), filtered 



count_dictionary(["a+"], positive)
# Out:
# (1, ['a+'])

# %%
#Metode 1
def count_dictionary2(document, dictionary):
    words = []
    for word in document:
           if word in dictionary:
                 words.append(word)
    count = len(words)
    return count

count_dictionary2(['a+'], positive)
# Out:
# 1

# %% [markdown]
# >**Ex 15.1.6:** Define two new columns (***positive_liu***, ***negative_liu***) in the dataframe applying the count_dictionary function to all tokenized documents with the positive and negative set as input.
#
# *Hint:* the `.apply()` method allows you to input named arguments matching your `count_dictionary()` function to input the sentiment dictionary.

# %%
# [Answer Ex 15.1.6]
df['positive_liu'] = reviews.apply(count_dictionary, dictionary=positive)
df['negative_liu'] = reviews.apply(count_dictionary, dictionary=negative)

df.head()
# Out:
#    Unnamed: 0                                         __domain__  \
# 0      159770        https://trustpilot.com/review/www.exmed.net
# 1      168724      https://trustpilot.com/review/mapscompany.com
# 2       96443  https://trustpilot.com/review/www.thriftbooks.com
# 3      173433        https://trustpilot.com/review/fabletics.com
# 4      138968   https://trustpilot.com/review/www.enterprise.com
#
#    address_@type address_addressCountry address_addressLocality  \
# 0  PostalAddress                    NaN                  Fenton
# 1  PostalAddress                    NaN        Petit-Rocher, NB
# 2  PostalAddress                    NaN                 Tukwila
# 3  PostalAddress                    NaN                     NaN
# 4  PostalAddress                     US                St Louis
#
#   address_postalCode         address_streetAddress author_@type  \
# 0              63026              218 Seebold Spur       Person
# 1            E8J 1E4             713 rue de la Mer       Person
# 2              98188  18300 Cascade Ave S, Ste 150       Person
# 3                NaN                           NaN       Person
# 4              63105         600 Corporate Park Dr       Person
#
#           datePublished                    email  ...       itemReviewed_name  \
# 0  2017-07-29T20:27:03Z          sales@exmed.net  ...  Express Medical Supply
# 1  2017-08-11T20:09:48Z  contact@mapscompany.com  ...             MapsCompany
# 2  2015-03-19T22:59:22Z  reviews@thriftbooks.com  ...            Thrift Books
# 3  2017-04-30T19:47:39Z                      NaN  ...               Fabletics
# 4  2018-05-26T20:43:41Z                      NaN  ...              Enterprise
#
#       meta_@type                    name  \
# 0  LocalBusiness  Express Medical Supply
# 1  LocalBusiness             MapsCompany
# 2  LocalBusiness            Thrift Books
# 3  LocalBusiness               Fabletics
# 4  LocalBusiness              Enterprise
#
#                                           reviewBody reviewRating_@type  \
# 0  Lots of inventory, very fast and efficient. I ...             Rating
# 1  I did not received the map I had ordered and p...             Rating
# 2  After searching a number of stores here in my ...             Rating
# 3  Website is not intuitive.  I don't like having...             Rating
# 4  Outstanding customer service, appreciated the ...             Rating
#
#   reviewRating_ratingValue       telephone         categories  positive_liu  \
# 0                        5  (800) 633-2139  /health_wellbeing             3
# 1                        3             NaN   /travel_holidays             3
# 2                        5    253-275-2251     /entertainment             5
# 3                        2    855-202-3570   /clothes_fashion             4
# 4                        5             NaN    /transportation             3
#
#   negative_liu
# 0            0
# 1            2
# 2            0
# 3            0
# 4            0
#
# [5 rows x 23 columns]

# %% [markdown]
# > **Ex 15.1.7 (BONUS):** Define your own set of words and use the count_dictionary function to match them (remember that they need to be lowercased to match).

# %%
# [Answer Ex 15.1.7]

# %% [markdown]
# ### Exercise 15 Part 2: Applying prepackaged rulebased dictionaries and comparison of results
# In the following exercise you will apply two prepackaged dictionaries which are also rulebased. One is MIT's VADER method (https://github.com/cjhutto/vaderSentiment) which is builtin to the NLTK package, and the Finn Aarups (DTU) AFINN sentiment analyzer, which has the advantage of working on danish text.

# %% [markdown]
# >**Ex 15.2.1:** Apply VADER: Define a four new columns using output from the VADER sentiment analyzer
# 1. Import the `nltk`, `nltk.sentiment` package and download the vader_lexicon using `nltk.download('vader_lexicon')`.
# 2. Initialize the the vader sentiment analyzer: nltk.sentiment.vader.SentimentIntensityAnalyzer()
# 3. Apply the `.polarity_scores` function to all documents. This function should be provided with a string. So, you do not need to tokenize the documents, but instead you can just use the ***reviewBody*** column of your dataframe.
# 4. Convert the resulting Series of dictionaries (Vader outputs dictionaries of 4 scores) to a dataframe by first converting the Series into a list using the `list()` function, and then the `pd.DataFrame()` function.
# 5. Rename the columns adding vader_ as prefix.
# 6. Merge with original Dataframe.
#
# *Hint:* Use `pd.concat([df,df2],axis=1)`

# %%
# [Answer Ex 15.2.1]
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\cecil\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sentiment = nltk.sentiment.vader.SentimentIntensityAnalyzer()

# %%
#df['polarity'] = df['reviewBody'].apply(sentiment.polarity_scores)
polarity = df['reviewBody'].apply(sentiment.polarity_scores)

# %%
df_list = list(polarity)

df[['vader_compound', 'vader_neg', 'vader_neu', 'vader_pos']] = pd.DataFrame(df_list)

#df['vader_compound', 'vader_neg', 'vader_neu', 'vader_pos']

df
# Out:
#       Unnamed: 0                                         __domain__  \
# 0         159770        https://trustpilot.com/review/www.exmed.net
# 1         168724      https://trustpilot.com/review/mapscompany.com
# 2          96443  https://trustpilot.com/review/www.thriftbooks.com
# 3         173433        https://trustpilot.com/review/fabletics.com
# 4         138968   https://trustpilot.com/review/www.enterprise.com
# 5          67290      https://trustpilot.com/review/newyorkpass.com
# 6          31913   https://trustpilot.com/review/www.comfysacks.com
# 7          40227    https://trustpilot.com/review/www.priceline.com
# 8         150471      https://trustpilot.com/review/mycomicshop.com
# 9         180105   https://trustpilot.com/review/www.shoedazzle.com
# 10           907      https://trustpilot.com/review/1800dentist.com
# 11         28064  https://trustpilot.com/review/www.pureformulas...
# 12         83452  https://trustpilot.com/review/www.allianztrave...
# 13         53981    https://trustpilot.com/review/vacuum-direct.com
# 14        126297         https://trustpilot.com/review/www.lang.com
# 15         98671   https://trustpilot.com/review/shipacardirect.com
# 16         49921  https://trustpilot.com/review/www.compliancesi...
# 17         36838   https://trustpilot.com/review/www.galahotels.com
# 18         15109   https://trustpilot.com/review/www.cashnetusa.com
# 19        107565  https://trustpilot.com/review/www.textbookrush...
# 20         35809       https://trustpilot.com/review/hellofresh.com
# 21         45903        https://trustpilot.com/review/www.amoma.com
# 22         36653      https://trustpilot.com/review/plaquemaker.com
# 23         96444  https://trustpilot.com/review/www.thriftbooks.com
# 24         66356  https://trustpilot.com/review/privateinterneta...
# 25          5417  https://trustpilot.com/review/www.textbookrush...
# 26        129783     https://trustpilot.com/review/www.airsplat.com
# 27        112494      https://trustpilot.com/review/plaquemaker.com
# 28         13623       https://trustpilot.com/review/careington.com
# 29         65407    https://trustpilot.com/review/www.cafepress.com
# ...          ...                                                ...
# 9970       58842    https://trustpilot.com/review/www.cafepress.com
# 9971      111968   https://trustpilot.com/review/thelogocompany.net
# 9972       75459  https://trustpilot.com/review/catholiccompany.com
# 9973      140752          https://trustpilot.com/review/tradesy.com
# 9974      135153        https://trustpilot.com/review/golfclubs.com
# 9975      138497  https://trustpilot.com/review/mysterytacklebox...
# 9976       46453       https://trustpilot.com/review/hellofresh.com
# 9977       28698  https://trustpilot.com/review/techliveconnect.com
# 9978      141414          https://trustpilot.com/review/justfly.com
# 9979      125471   https://trustpilot.com/review/www.bookrenter.com
# 9980       50299  https://trustpilot.com/review/www.oktoberfesth...
# 9981      163976   https://trustpilot.com/review/www.timberland.com
# 9982      136532    https://trustpilot.com/review/www.partsgeek.com
# 9983       24347        https://trustpilot.com/review/www.reeds.com
# 9984      113836          https://trustpilot.com/review/justfly.com
# 9985      176062    https://trustpilot.com/review/www.partsgeek.com
# 9986       43073   https://trustpilot.com/review/airparkparking.com
# 9987       63520         https://trustpilot.com/review/www.xoom.com
# 9988      175268      https://trustpilot.com/review/greenvelope.com
# 9989      145374   https://trustpilot.com/review/www.cartrawler.com
# 9990       91617    https://trustpilot.com/review/www.cafepress.com
# 9991       19692    https://trustpilot.com/review/www.cafepress.com
# 9992      140837            https://trustpilot.com/review/dial7.com
# 9993      113870  https://trustpilot.com/review/www.mileskimball...
# 9994       62697  https://trustpilot.com/review/www.textbookrush...
# 9995       89738  https://trustpilot.com/review/www.pureformulas...
# 9996      118726      https://trustpilot.com/review/impactsigns.com
# 9997       60622              https://trustpilot.com/review/nfm.com
# 9998       94658  https://trustpilot.com/review/www.airportparki...
# 9999      165552   https://trustpilot.com/review/www.creditloan.com
#
#       address_@type address_addressCountry  address_addressLocality  \
# 0     PostalAddress                    NaN                   Fenton
# 1     PostalAddress                    NaN         Petit-Rocher, NB
# 2     PostalAddress                    NaN                  Tukwila
# 3     PostalAddress                    NaN                      NaN
# 4     PostalAddress                     US                 St Louis
# 5     PostalAddress                    NaN            New York City
# 6     PostalAddress                     US              Saint Louis
# 7     PostalAddress                     US                      NaN
# 8     PostalAddress                    NaN                Arlington
# 9     PostalAddress                     US                      NaN
# 10    PostalAddress                    NaN              Los Angeles
# 11    PostalAddress                    NaN                   Medley
# 12    PostalAddress                    NaN                 Richmond
# 13    PostalAddress                     US                  Bad Axe
# 14    PostalAddress                    NaN                 Waukesha
# 15    PostalAddress                    NaN                      NaN
# 16    PostalAddress                    NaN             Chadwick, IL
# 17    PostalAddress                    NaN  Mecidiyekoy / Istanbul
# 18    PostalAddress                    NaN              Chicago, IL
# 19    PostalAddress                    NaN                      NaN
# 20    PostalAddress                    NaN                      NaN
# 21    PostalAddress                     US                   Genève
# 22    PostalAddress                    NaN                Fortville
# 23    PostalAddress                    NaN                  Tukwila
# 24    PostalAddress                    NaN                      NaN
# 25    PostalAddress                    NaN                      NaN
# 26    PostalAddress                    NaN                      NaN
# 27    PostalAddress                    NaN                Fortville
# 28    PostalAddress                    NaN                   Frisco
# 29    PostalAddress                    NaN                      NaN
# ...             ...                    ...                      ...
# 9970  PostalAddress                    NaN                      NaN
# 9971  PostalAddress                    NaN                 New York
# 9972  PostalAddress                    NaN                Charlotte
# 9973  PostalAddress                    NaN   Santa Monica, CA 90401
# 9974  PostalAddress                     US                 Portland
# 9975  PostalAddress                    NaN                      NaN
# 9976  PostalAddress                    NaN                      NaN
# 9977  PostalAddress                     US                      NaN
# 9978  PostalAddress                    NaN                      NaN
# 9979  PostalAddress                    NaN                San Mateo
# 9980  PostalAddress                    NaN                Roseville
# 9981  PostalAddress                    NaN                      NaN
# 9982  PostalAddress                    NaN                  Marlton
# 9983  PostalAddress                    NaN               Wilmington
# 9984  PostalAddress                    NaN                      NaN
# 9985  PostalAddress                    NaN                  Marlton
# 9986  PostalAddress                     US                  Jamaica
# 9987  PostalAddress                    NaN            San Francisco
# 9988  PostalAddress                    NaN                  Seattle
# 9989  PostalAddress                     IE                  Dublin
# 9990  PostalAddress                    NaN                      NaN
# 9991  PostalAddress                    NaN                      NaN
# 9992  PostalAddress                    NaN     Long Island City, NY
# 9993  PostalAddress                     US                  Oshkosh
# 9994  PostalAddress                    NaN                      NaN
# 9995  PostalAddress                    NaN                   Medley
# 9996  PostalAddress                    NaN                 LaGrange
# 9997  PostalAddress                    NaN                    Omaha
# 9998  PostalAddress                    NaN             Santa Monica
# 9999  PostalAddress                     US                    Tampa
#
#      address_postalCode                              address_streetAddress  \
# 0                 63026                                   218 Seebold Spur
# 1               E8J 1E4                                  713 rue de la Mer
# 2                 98188                       18300 Cascade Ave S, Ste 150
# 3                   NaN                                                NaN
# 4                 63105                              600 Corporate Park Dr
# 5              NY 10036                               36 West 44th Street
# 6                 63114                  1976 Innerbelt Business Center Dr
# 7                   NaN                                                NaN
# 8                 76010                                1800 Timberlake Dr.
# 9                   NaN                                                NaN
# 10                90045                                  6060 Center Drive
# 11                33178                          11800 NW 102 Road Suite 2
# 12                23233                                 9950 Mayland Drive
# 13                48413                                      980 Ubly Road
# 14                53187                                        PO Box 1605
# 15                  NaN                                                NaN
# 16                61014                               56 South Main Street
# 17             TR 34394  Gulbahar Mh. Harmanyolu Ust Sk. Meric Plaza No...
# 18                60604                                   175 West Jackson
# 19                  NaN                                                NaN
# 20                  NaN                                                NaN
# 21                 1201                                     Quai Wilson 45
# 22                46040                            289 Business Park Drive
# 23                98188                       18300 Cascade Ave S, Ste 150
# 24                  NaN                                                NaN
# 25                  NaN                                                NaN
# 26                  NaN                                                NaN
# 27                46040                            289 Business Park Drive
# 28                75034                               7400 Gaylord Parkway
# 29                  NaN                                                NaN
# ...                 ...                                                ...
# 9970                NaN                                                NaN
# 9971              10036             1180 Avenue of the Americas- 8th Floor
# 9972              28273                            615 E Westinghouse Blvd
# 9973                NaN                         1217 2nd Street, 4th Floor
# 9974                NaN                                                NaN
# 9975                NaN                                                NaN
# 9976                NaN                                                NaN
# 9977                NaN                                                NaN
# 9978                NaN                                                NaN
# 9979              94403                         1200 Park Place, Suite 250
# 9980              55113                                2001 County Rd C2 W
# 9981                NaN                                                NaN
# 9982              08053                      777 Route 70 East Suite G-103
# 9983              28402                                        PO Box 2229
# 9984                NaN                                                NaN
# 9985              08053                      777 Route 70 East Suite G-103
# 9986              11434                           153-44 South Conduit Ave
# 9987              94105                                         425 Market
# 9988              98101                         1620 4th Avenue, Suite 200
# 9989                NaN    Classon House, Dundrum Business Park, Dublin 14
# 9990                NaN                                                NaN
# 9991                NaN                                                NaN
# 9992              11101                                  43-23 35th Street
# 9993              54906                                    250 City Center
# 9994                NaN                                                NaN
# 9995              33178                          11800 NW 102 Road Suite 2
# 9996              60525                                26 E Burlington Ave
# 9997              68114                                      700 S 72nd ST
# 9998              90401                          1640 5th Street Suite 202
# 9999              33607                2202 N. West Shore Blvd., Suite 200
#
#      author_@type         datePublished  \
# 0          Person  2017-07-29T20:27:03Z
# 1          Person  2017-08-11T20:09:48Z
# 2          Person  2015-03-19T22:59:22Z
# 3          Person  2017-04-30T19:47:39Z
# 4          Person  2018-05-26T20:43:41Z
# 5          Person  2017-04-21T16:07:53Z
# 6          Person  2014-03-03T22:40:21Z
# 7          Person  2014-12-30T15:06:07Z
# 8          Person  2015-12-09T22:39:48Z
# 9          Person  2015-11-10T17:41:44Z
# 10         Person  2017-06-12T14:20:34Z
# 11         Person  2013-08-01T12:22:36Z
# 12         Person  2015-08-17T16:54:09Z
# 13         Person  2017-01-23T22:40:19Z
# 14         Person  2017-01-03T17:18:09Z
# 15         Person  2014-04-23T16:45:53Z
# 16         Person  2015-03-12T21:09:52Z
# 17         Person  2017-06-23T09:48:35Z
# 18         Person  2017-11-14T18:41:13Z
# 19         Person  2015-02-10T20:24:17Z
# 20         Person  2018-03-06T20:47:10Z
# 21         Person  2017-03-22T19:42:16Z
# 22         Person  2014-01-10T22:04:27Z
# 23         Person  2015-03-19T22:38:24Z
# 24         Person  2016-03-15T23:48:30Z
# 25         Person  2017-12-08T23:12:17Z
# 26         Person  2016-09-08T01:28:32Z
# 27         Person  2016-03-09T22:30:40Z
# 28         Person  2017-08-29T20:15:17Z
# 29         Person  2016-12-19T12:19:24Z
# ...           ...                   ...
# 9970       Person  2018-05-30T19:31:44Z
# 9971       Person  2016-02-01T01:53:41Z
# 9972       Person  2017-10-30T15:01:08Z
# 9973       Person  2017-06-06T22:12:21Z
# 9974       Person  2015-02-09T00:50:22Z
# 9975       Person  2014-09-03T17:47:23Z
# 9976       Person  2017-05-18T21:59:58Z
# 9977       Person  2017-12-06T22:41:02Z
# 9978       Person  2016-06-04T17:54:51Z
# 9979       Person  2014-11-08T21:11:05Z
# 9980       Person  2014-10-30T13:42:30Z
# 9981       Person  2017-08-08T02:54:54Z
# 9982       Person  2014-08-10T15:51:03Z
# 9983       Person  2015-06-07T12:15:13Z
# 9984       Person  2016-10-05T18:29:44Z
# 9985       Person  2015-05-14T16:26:34Z
# 9986       Person  2017-05-16T01:26:02Z
# 9987       Person  2018-08-10T00:02:40Z
# 9988       Person  2017-05-10T17:51:49Z
# 9989       Person  2017-07-26T18:11:14Z
# 9990       Person  2015-07-14T10:15:06Z
# 9991       Person  2014-09-22T19:26:27Z
# 9992       Person  2016-01-13T05:01:02Z
# 9993       Person  2017-12-19T01:21:44Z
# 9994       Person  2016-12-17T01:04:37Z
# 9995       Person  2013-07-28T14:55:42Z
# 9996       Person  2017-09-25T20:59:10Z
# 9997       Person  2018-07-31T00:58:41Z
# 9998       Person  2018-07-21T01:17:08Z
# 9999       Person  2014-02-08T00:48:56Z
#
#                                        email  ...  \
# 0                            sales@exmed.net  ...
# 1                    contact@mapscompany.com  ...
# 2                    reviews@thriftbooks.com  ...
# 3                                        NaN  ...
# 4                                        NaN  ...
# 5                       info@newyorkpass.com  ...
# 6                        Info@ComfySacks.com  ...
# 7                                        NaN  ...
# 8                    service@mycomicshop.com  ...
# 9                                        NaN  ...
# 10                  feedback@1800dentist.com  ...
# 11                     help@pureformulas.com  ...
# 12           help.team@allianzassistance.com  ...
# 13                   sales@vacuum-direct.com  ...
# 14                          service@lang.com  ...
# 15                                       NaN  ...
# 16                 Sales@compliancesigns.com  ...
# 17                       info@galahotels.com  ...
# 18                    support@cashnetusa.com  ...
# 19                     help@textbookrush.com  ...
# 20                      hello@hellofresh.com  ...
# 21                         support@amoma.com  ...
# 22                      help@plaquemaker.com  ...
# 23                   reviews@thriftbooks.com  ...
# 24         support@privateinternetaccess.com  ...
# 25                     help@textbookrush.com  ...
# 26                                       NaN  ...
# 27                      help@plaquemaker.com  ...
# 28                       info@careington.com  ...
# 29                      social@cafepress.com  ...
# ...                                      ...  ...
# 9970                    social@cafepress.com  ...
# 9971             logosale@thelogocompany.net  ...
# 9972     customerservice@catholiccompany.com  ...
# 9973                        team@tradesy.com  ...
# 9974               sales@golfclubsdirect.com  ...
# 9975            support@mysterytacklebox.com  ...
# 9976                    hello@hellofresh.com  ...
# 9977             support@techliveconnect.com  ...
# 9978                      Social@justfly.com  ...
# 9979                     info@bookrenter.com  ...
# 9980                info@oktoberfesthaus.com  ...
# 9981                                     NaN  ...
# 9982                                     NaN  ...
# 9983                        orders@reeds.com  ...
# 9984                      Social@justfly.com  ...
# 9985                                     NaN  ...
# 9986                 info@airparkparking.com  ...
# 9987           customersatisfaction@xoom.com  ...
# 9988                    info@greenvelope.com  ...
# 9989                    hello@cartrawler.com  ...
# 9990                    social@cafepress.com  ...
# 9991                    social@cafepress.com  ...
# 9992                            cs@dial7.com  ...
# 9993                    CSR@MilesKimball.com  ...
# 9994                   help@textbookrush.com  ...
# 9995                   help@pureformulas.com  ...
# 9996                 shabbir@impactsigns.com  ...
# 9997                                     NaN  ...
# 9998  service@airportparkingreservations.com  ...
# 9999                 feedback@creditloan.com  ...
#
#                                               telephone  \
# 0                                        (800) 633-2139
# 1                                                   NaN
# 2                                          253-275-2251
# 3                                          855-202-3570
# 4                                                   NaN
# 5                                      1 (877) 714-1999
# 6                                            8778843826
# 7                                                   NaN
# 8                                          817-860-7827
# 9                                          888.508.1888
# 10                                         310-215-6400
# 11                                       1-800-383-6008
# 12                                       1-866-884-3556
# 13                                       1-866-927-4327
# 14                                       1-800-967-3399
# 15                                                  NaN
# 16                                       1-800-578-1245
# 17                                   0044 20 3384 64 48
# 18                                         888.801.9075
# 19                                       (614) 729-2477
# 20                                         646-846-3663
# 21                                         +41225182013
# 22                                       1-866-880-9617
# 23                                         253-275-2251
# 24                                                  NaN
# 25                                       (614) 729-2477
# 26                                                  NaN
# 27                                       1-866-880-9617
# 28                                       (800) 290-0523
# 29                                       1-877-809-1659
# ...                                                 ...
# 9970                                     1-877-809-1659
# 9971                                       212-382-4644
# 9972                                       866-522-8465
# 9973  +1-310-912-7966                               ...
# 9974                                       800-391-9332
# 9975                                                NaN
# 9976                                       646-846-3663
# 9977                                                NaN
# 9978                                     1-800-717-5015
# 9979                                                NaN
# 9980                                     (877) 577-2801
# 9981                                                NaN
# 9982                                                NaN
# 9983                                       877-406-3266
# 9984                                     1-800-717-5015
# 9985                                                NaN
# 9986                                       718-276-7000
# 9987                                     (877) 815-1531
# 9988                                       888-505-2588
# 9989                                                NaN
# 9990                                     1-877-809-1659
# 9991                                     1-877-809-1659
# 9992                                       212-777-7777
# 9993                                       855-202-7394
# 9994                                     (614) 729-2477
# 9995                                     1-800-383-6008
# 9996                                       708-469-7178
# 9997                                       800-336-9136
# 9998                                                NaN
# 9999                                         8135270728
#
#                          categories positive_liu negative_liu  \
# 0                 /health_wellbeing            3            0
# 1                  /travel_holidays            3            2
# 2                    /entertainment            5            0
# 3                  /clothes_fashion            4            0
# 4                   /transportation            3            0
# 5                  /travel_holidays            2            0
# 6                      /home_garden           15            2
# 7                  /travel_holidays            0            2
# 8                    /entertainment            1            0
# 9                  /clothes_fashion            2            2
# 10                /health_wellbeing            0            0
# 11                /health_wellbeing            1            0
# 12          /money,/travel_holidays            3            1
# 13                     /home_garden            1            0
# 14                             /art            1            1
# 15                  /transportation            4            0
# 16                  /art,/companies            8            0
# 17                 /travel_holidays            8            1
# 18                           /money            1            0
# 19                   /entertainment            0            1
# 20                   /food_beverage            5            0
# 21                 /travel_holidays            2            0
# 22                             /art            1            0
# 23                   /entertainment            2            0
# 24                        /computer            1            0
# 25                   /entertainment            2            0
# 26                         /leisure            2            0
# 27                             /art            2            0
# 28                /health_wellbeing            3            0
# 29                 /clothes_fashion            4            0
# ...                             ...          ...          ...
# 9970               /clothes_fashion            2            1
# 9971                /art,/companies            5            0
# 9972               /clothes_fashion            3            0
# 9973               /clothes_fashion            1            6
# 9974                         /sport            0            0
# 9975                       /leisure            0            0
# 9976                 /food_beverage            5            0
# 9977                     /companies            2            0
# 9978               /travel_holidays            2            0
# 9979               /public_services            0            0
# 9980  /clothes_fashion,/home_garden            2            1
# 9981               /clothes_fashion            1            3
# 9982                /transportation            2            1
# 9983               /clothes_fashion            0            0
# 9984               /travel_holidays            1            0
# 9985                /transportation            1            1
# 9986               /travel_holidays            4            1
# 9987                         /money            4            0
# 9988                 /entertainment            1            0
# 9989                /transportation            1            0
# 9990               /clothes_fashion            4            2
# 9991               /clothes_fashion            2            2
# 9992                /transportation            3            0
# 9993                   /home_garden            1            0
# 9994                 /entertainment            3            4
# 9995              /health_wellbeing            3            2
# 9996                     /companies            0            1
# 9997      /electronics,/home_garden            1            0
# 9998               /travel_holidays            7            3
# 9999                         /money            2            0
#
#                                                polarity  \
# 0     {'neg': 0.0, 'neu': 0.618, 'pos': 0.382, 'comp...
# 1     {'neg': 0.058, 'neu': 0.783, 'pos': 0.158, 'co...
# 2     {'neg': 0.0, 'neu': 0.882, 'pos': 0.118, 'comp...
# 3     {'neg': 0.0, 'neu': 0.734, 'pos': 0.266, 'comp...
# 4     {'neg': 0.0, 'neu': 0.479, 'pos': 0.521, 'comp...
# 5     {'neg': 0.087, 'neu': 0.751, 'pos': 0.162, 'co...
# 6     {'neg': 0.006, 'neu': 0.782, 'pos': 0.212, 'co...
# 7     {'neg': 0.072, 'neu': 0.882, 'pos': 0.046, 'co...
# 8     {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'comp...
# 9     {'neg': 0.499, 'neu': 0.334, 'pos': 0.167, 'co...
# 10    {'neg': 0.0, 'neu': 0.887, 'pos': 0.113, 'comp...
# 11    {'neg': 0.0, 'neu': 0.258, 'pos': 0.742, 'comp...
# 12    {'neg': 0.144, 'neu': 0.535, 'pos': 0.321, 'co...
# 13    {'neg': 0.0, 'neu': 0.721, 'pos': 0.279, 'comp...
# 14    {'neg': 0.204, 'neu': 0.667, 'pos': 0.129, 'co...
# 15    {'neg': 0.01, 'neu': 0.898, 'pos': 0.093, 'com...
# 16    {'neg': 0.0, 'neu': 0.676, 'pos': 0.324, 'comp...
# 17    {'neg': 0.05, 'neu': 0.623, 'pos': 0.327, 'com...
# 18    {'neg': 0.0, 'neu': 0.417, 'pos': 0.583, 'comp...
# 19    {'neg': 0.189, 'neu': 0.811, 'pos': 0.0, 'comp...
# 20    {'neg': 0.0, 'neu': 0.706, 'pos': 0.294, 'comp...
# 21    {'neg': 0.0, 'neu': 0.448, 'pos': 0.552, 'comp...
# 22    {'neg': 0.0, 'neu': 0.684, 'pos': 0.316, 'comp...
# 23    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 24    {'neg': 0.0, 'neu': 0.722, 'pos': 0.278, 'comp...
# 25    {'neg': 0.0, 'neu': 0.63, 'pos': 0.37, 'compou...
# 26    {'neg': 0.0, 'neu': 0.683, 'pos': 0.317, 'comp...
# 27    {'neg': 0.0, 'neu': 0.874, 'pos': 0.126, 'comp...
# 28    {'neg': 0.0, 'neu': 0.451, 'pos': 0.549, 'comp...
# 29    {'neg': 0.0, 'neu': 0.447, 'pos': 0.553, 'comp...
# ...                                                 ...
# 9970  {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'comp...
# 9971  {'neg': 0.043, 'neu': 0.875, 'pos': 0.083, 'co...
# 9972  {'neg': 0.0, 'neu': 0.649, 'pos': 0.351, 'comp...
# 9973  {'neg': 0.105, 'neu': 0.816, 'pos': 0.079, 'co...
# 9974  {'neg': 0.0, 'neu': 0.792, 'pos': 0.208, 'comp...
# 9975  {'neg': 0.0, 'neu': 0.638, 'pos': 0.362, 'comp...
# 9976  {'neg': 0.0, 'neu': 0.536, 'pos': 0.464, 'comp...
# 9977  {'neg': 0.0, 'neu': 0.539, 'pos': 0.461, 'comp...
# 9978  {'neg': 0.0, 'neu': 0.521, 'pos': 0.479, 'comp...
# 9979  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 9980  {'neg': 0.132, 'neu': 0.799, 'pos': 0.069, 'co...
# 9981  {'neg': 0.389, 'neu': 0.531, 'pos': 0.08, 'com...
# 9982  {'neg': 0.0, 'neu': 0.91, 'pos': 0.09, 'compou...
# 9983  {'neg': 0.0, 'neu': 0.939, 'pos': 0.061, 'comp...
# 9984  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 9985  {'neg': 0.035, 'neu': 0.919, 'pos': 0.046, 'co...
# 9986  {'neg': 0.0, 'neu': 0.879, 'pos': 0.121, 'comp...
# 9987  {'neg': 0.0, 'neu': 0.559, 'pos': 0.441, 'comp...
# 9988  {'neg': 0.065, 'neu': 0.885, 'pos': 0.05, 'com...
# 9989  {'neg': 0.0, 'neu': 0.448, 'pos': 0.552, 'comp...
# 9990  {'neg': 0.085, 'neu': 0.703, 'pos': 0.212, 'co...
# 9991  {'neg': 0.0, 'neu': 0.879, 'pos': 0.121, 'comp...
# 9992  {'neg': 0.0, 'neu': 0.723, 'pos': 0.277, 'comp...
# 9993  {'neg': 0.0, 'neu': 0.854, 'pos': 0.146, 'comp...
# 9994  {'neg': 0.107, 'neu': 0.789, 'pos': 0.104, 'co...
# 9995  {'neg': 0.029, 'neu': 0.831, 'pos': 0.14, 'com...
# 9996  {'neg': 0.161, 'neu': 0.839, 'pos': 0.0, 'comp...
# 9997  {'neg': 0.0, 'neu': 0.714, 'pos': 0.286, 'comp...
# 9998  {'neg': 0.036, 'neu': 0.723, 'pos': 0.241, 'co...
# 9999  {'neg': 0.0, 'neu': 0.86, 'pos': 0.14, 'compou...
#
#                                        (polarity, , , ) vader_compound  \
# 0     {'neg': 0.0, 'neu': 0.618, 'pos': 0.382, 'comp...         0.6771
# 1     {'neg': 0.058, 'neu': 0.783, 'pos': 0.158, 'co...         0.8836
# 2     {'neg': 0.0, 'neu': 0.882, 'pos': 0.118, 'comp...         0.6124
# 3     {'neg': 0.0, 'neu': 0.734, 'pos': 0.266, 'comp...         0.7664
# 4     {'neg': 0.0, 'neu': 0.479, 'pos': 0.521, 'comp...         0.8977
# 5     {'neg': 0.087, 'neu': 0.751, 'pos': 0.162, 'co...         0.6360
# 6     {'neg': 0.006, 'neu': 0.782, 'pos': 0.212, 'co...         0.9926
# 7     {'neg': 0.072, 'neu': 0.882, 'pos': 0.046, 'co...        -0.2878
# 8     {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'comp...         0.6249
# 9     {'neg': 0.499, 'neu': 0.334, 'pos': 0.167, 'co...        -0.6080
# 10    {'neg': 0.0, 'neu': 0.887, 'pos': 0.113, 'comp...         0.4215
# 11    {'neg': 0.0, 'neu': 0.258, 'pos': 0.742, 'comp...         0.6962
# 12    {'neg': 0.144, 'neu': 0.535, 'pos': 0.321, 'co...         0.5106
# 13    {'neg': 0.0, 'neu': 0.721, 'pos': 0.279, 'comp...         0.5400
# 14    {'neg': 0.204, 'neu': 0.667, 'pos': 0.129, 'co...        -0.2040
# 15    {'neg': 0.01, 'neu': 0.898, 'pos': 0.093, 'com...         0.8885
# 16    {'neg': 0.0, 'neu': 0.676, 'pos': 0.324, 'comp...         0.9455
# 17    {'neg': 0.05, 'neu': 0.623, 'pos': 0.327, 'com...         0.9533
# 18    {'neg': 0.0, 'neu': 0.417, 'pos': 0.583, 'comp...         0.4215
# 19    {'neg': 0.189, 'neu': 0.811, 'pos': 0.0, 'comp...        -0.5994
# 20    {'neg': 0.0, 'neu': 0.706, 'pos': 0.294, 'comp...         0.9583
# 21    {'neg': 0.0, 'neu': 0.448, 'pos': 0.552, 'comp...         0.8126
# 22    {'neg': 0.0, 'neu': 0.684, 'pos': 0.316, 'comp...         0.7184
# 23    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...         0.0000
# 24    {'neg': 0.0, 'neu': 0.722, 'pos': 0.278, 'comp...         0.4005
# 25    {'neg': 0.0, 'neu': 0.63, 'pos': 0.37, 'compou...         0.5719
# 26    {'neg': 0.0, 'neu': 0.683, 'pos': 0.317, 'comp...         0.8316
# 27    {'neg': 0.0, 'neu': 0.874, 'pos': 0.126, 'comp...         0.4877
# 28    {'neg': 0.0, 'neu': 0.451, 'pos': 0.549, 'comp...         0.8070
# 29    {'neg': 0.0, 'neu': 0.447, 'pos': 0.553, 'comp...         0.8720
# ...                                                 ...            ...
# 9970  {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'comp...         0.8313
# 9971  {'neg': 0.043, 'neu': 0.875, 'pos': 0.083, 'co...         0.3867
# 9972  {'neg': 0.0, 'neu': 0.649, 'pos': 0.351, 'comp...         0.7964
# 9973  {'neg': 0.105, 'neu': 0.816, 'pos': 0.079, 'co...        -0.7645
# 9974  {'neg': 0.0, 'neu': 0.792, 'pos': 0.208, 'comp...         0.2732
# 9975  {'neg': 0.0, 'neu': 0.638, 'pos': 0.362, 'comp...         0.6249
# 9976  {'neg': 0.0, 'neu': 0.536, 'pos': 0.464, 'comp...         0.9473
# 9977  {'neg': 0.0, 'neu': 0.539, 'pos': 0.461, 'comp...         0.7178
# 9978  {'neg': 0.0, 'neu': 0.521, 'pos': 0.479, 'comp...         0.5574
# 9979  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...         0.0000
# 9980  {'neg': 0.132, 'neu': 0.799, 'pos': 0.069, 'co...        -0.3167
# 9981  {'neg': 0.389, 'neu': 0.531, 'pos': 0.08, 'com...        -0.8591
# 9982  {'neg': 0.0, 'neu': 0.91, 'pos': 0.09, 'compou...         0.7574
# 9983  {'neg': 0.0, 'neu': 0.939, 'pos': 0.061, 'comp...         0.2057
# 9984  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...         0.0000
# 9985  {'neg': 0.035, 'neu': 0.919, 'pos': 0.046, 'co...         0.1779
# 9986  {'neg': 0.0, 'neu': 0.879, 'pos': 0.121, 'comp...         0.8428
# 9987  {'neg': 0.0, 'neu': 0.559, 'pos': 0.441, 'comp...         0.9429
# 9988  {'neg': 0.065, 'neu': 0.885, 'pos': 0.05, 'com...         0.0490
# 9989  {'neg': 0.0, 'neu': 0.448, 'pos': 0.552, 'comp...         0.5719
# 9990  {'neg': 0.085, 'neu': 0.703, 'pos': 0.212, 'co...         0.8398
# 9991  {'neg': 0.0, 'neu': 0.879, 'pos': 0.121, 'comp...         0.7096
# 9992  {'neg': 0.0, 'neu': 0.723, 'pos': 0.277, 'comp...         0.7841
# 9993  {'neg': 0.0, 'neu': 0.854, 'pos': 0.146, 'comp...         0.3384
# 9994  {'neg': 0.107, 'neu': 0.789, 'pos': 0.104, 'co...         0.5642
# 9995  {'neg': 0.029, 'neu': 0.831, 'pos': 0.14, 'com...         0.8126
# 9996  {'neg': 0.161, 'neu': 0.839, 'pos': 0.0, 'comp...        -0.7783
# 9997  {'neg': 0.0, 'neu': 0.714, 'pos': 0.286, 'comp...         0.6808
# 9998  {'neg': 0.036, 'neu': 0.723, 'pos': 0.241, 'co...         0.9648
# 9999  {'neg': 0.0, 'neu': 0.86, 'pos': 0.14, 'compou...         0.8519
#
#      vader_neg  vader_neu vader_pos
# 0        0.000      0.618     0.382
# 1        0.058      0.783     0.158
# 2        0.000      0.882     0.118
# 3        0.000      0.734     0.266
# 4        0.000      0.479     0.521
# 5        0.087      0.751     0.162
# 6        0.006      0.782     0.212
# 7        0.072      0.882     0.046
# 8        0.000      0.196     0.804
# 9        0.499      0.334     0.167
# 10       0.000      0.887     0.113
# 11       0.000      0.258     0.742
# 12       0.144      0.535     0.321
# 13       0.000      0.721     0.279
# 14       0.204      0.667     0.129
# 15       0.010      0.898     0.093
# 16       0.000      0.676     0.324
# 17       0.050      0.623     0.327
# 18       0.000      0.417     0.583
# 19       0.189      0.811     0.000
# 20       0.000      0.706     0.294
# 21       0.000      0.448     0.552
# 22       0.000      0.684     0.316
# 23       0.000      1.000     0.000
# 24       0.000      0.722     0.278
# 25       0.000      0.630     0.370
# 26       0.000      0.683     0.317
# 27       0.000      0.874     0.126
# 28       0.000      0.451     0.549
# 29       0.000      0.447     0.553
# ...        ...        ...       ...
# 9970     0.000      0.625     0.375
# 9971     0.043      0.875     0.083
# 9972     0.000      0.649     0.351
# 9973     0.105      0.816     0.079
# 9974     0.000      0.792     0.208
# 9975     0.000      0.638     0.362
# 9976     0.000      0.536     0.464
# 9977     0.000      0.539     0.461
# 9978     0.000      0.521     0.479
# 9979     0.000      1.000     0.000
# 9980     0.132      0.799     0.069
# 9981     0.389      0.531     0.080
# 9982     0.000      0.910     0.090
# 9983     0.000      0.939     0.061
# 9984     0.000      1.000     0.000
# 9985     0.035      0.919     0.046
# 9986     0.000      0.879     0.121
# 9987     0.000      0.559     0.441
# 9988     0.065      0.885     0.050
# 9989     0.000      0.448     0.552
# 9990     0.085      0.703     0.212
# 9991     0.000      0.879     0.121
# 9992     0.000      0.723     0.277
# 9993     0.000      0.854     0.146
# 9994     0.107      0.789     0.104
# 9995     0.029      0.831     0.140
# 9996     0.161      0.839     0.000
# 9997     0.000      0.714     0.286
# 9998     0.036      0.723     0.241
# 9999     0.000      0.860     0.140
#
# [10000 rows x 29 columns]

# %% [markdown]
# >**Ex 15.2.2:** Install the AFINN package: `pip install afinn`. Read how to apply the afinn package here (https://github.com/fnielsen/afinn) and define a column called afinn.
#
# *Hint:* As VADER's `polarity_score`, AFINN should be provided with a string and not the tokenized documents.

# %%
# [Answer Ex 15.2.2]
from afinn import Afinn

# %%
afinn = Afinn()
df['afinn'] = df['reviewBody'].apply(afinn.score)

df.head(3)
# Out:
#    Unnamed: 0                                         __domain__  \
# 0      159770        https://trustpilot.com/review/www.exmed.net
# 1      168724      https://trustpilot.com/review/mapscompany.com
# 2       96443  https://trustpilot.com/review/www.thriftbooks.com
#
#    address_@type address_addressCountry address_addressLocality  \
# 0  PostalAddress                    NaN                  Fenton
# 1  PostalAddress                    NaN        Petit-Rocher, NB
# 2  PostalAddress                    NaN                 Tukwila
#
#   address_postalCode         address_streetAddress author_@type  \
# 0              63026              218 Seebold Spur       Person
# 1            E8J 1E4             713 rue de la Mer       Person
# 2              98188  18300 Cascade Ave S, Ste 150       Person
#
#           datePublished                    email  ...         categories  \
# 0  2017-07-29T20:27:03Z          sales@exmed.net  ...  /health_wellbeing
# 1  2017-08-11T20:09:48Z  contact@mapscompany.com  ...   /travel_holidays
# 2  2015-03-19T22:59:22Z  reviews@thriftbooks.com  ...     /entertainment
#
#   positive_liu negative_liu  \
# 0            3            0
# 1            3            2
# 2            5            0
#
#                                             polarity  \
# 0  {'neg': 0.0, 'neu': 0.618, 'pos': 0.382, 'comp...
# 1  {'neg': 0.058, 'neu': 0.783, 'pos': 0.158, 'co...
# 2  {'neg': 0.0, 'neu': 0.882, 'pos': 0.118, 'comp...
#
#                                     (polarity, , , ) vader_compound vader_neg  \
# 0  {'neg': 0.0, 'neu': 0.618, 'pos': 0.382, 'comp...         0.6771     0.000
# 1  {'neg': 0.058, 'neu': 0.783, 'pos': 0.158, 'co...         0.8836     0.058
# 2  {'neg': 0.0, 'neu': 0.882, 'pos': 0.118, 'comp...         0.6124     0.000
#
#   vader_neu  vader_pos afinn
# 0     0.618      0.382   2.0
# 1     0.783      0.158   6.0
# 2     0.882      0.118   5.0
#
# [3 rows x 30 columns]

# %% [markdown]
# >**Ex 15.2.3:** Plot all the different dictionary and rulebased sentiment analysis columns against each other using the seaborn plotting function `sns.pairplot`. Set the color (i.e. hue argument as the number of stars in the `reviewRating_ratingValue` column).
#
# *Hint:* To plot, work with a smaller dataframe. You shoul select only the relevant columns, i.e. the ones with the sentiment analysis results and the star rating column. Moreover, you can downsample the dataframe to 1000 rows using the `.sample()` method.

# %%
# [Answer Ex 15.2.3]

df_new = df[['positive_liu', 'negative_liu', 'vader_compound', 'vader_neg', 'vader_neu', 'vader_pos', 'reviewRating_ratingValue']].sample(1000)
sns.pairplot(df_new, hue='reviewRating_ratingValue')
# Out:
# C:\Users\cecil\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\cecil\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
df_new.plot()

# %% [markdown]
# >**Ex 15.2.4:** Inspect a document where the LIU and VADER dictionaries disagree. More specifically, look at documents where the LIU lexicon is positive and the VADER is negative. For that, you should filter on positive expressions by LIU, and sample in the most negative according to the VADER. Try to explain the disagreement in terms of simple matches versus negations.
#
# *Hint*: Pick a document and see which words the LIU lexicon has matched using python set notation: e.g.
#
# ```python
# # overlap between two sets
# set(documents[0])&positive
# ```

# %%
# [Answer Ex 15.2.4]
#set(reviews[0])&positive_liu

## NOT DONE
positive_liu = df['positive_liu']
vader = df['vader_compound']

list1 = positive_liu

is_pos = lambda x: x> 0

output = list(filter(is_pos, list1))

# Python code to filter even values from a list 

list2 = vader
is_neg = lambda x: x<0

output2 = list(filter(is_neg, list2))

output2

# %% [markdown]
# ## Exercise 15 Part 3: Train a classifier to score the reviews and compare results
# In following exercise you will implement a simple text classifier based on the logistic regression trained on the ratings. We will walk through the standard procedures of Supervised Learning - i.e. parameter search and crossvalidation - but first we need to transform our documents into feature vectors. Here, we will use the sklearn function `sklearn.feature_extraction.text.CountVectorizer`. This module will transform the documents into BoWs (bag of words), using words counts and combinations of words (i.e. ngram) as columns.
#
# > **Ex 15.3.1:** Make a train-test (50-50) split before applying any transformation to avoid *data leakage* and to set up a clean hyperparameter search using the train set, and saving the test set for crossvalidation.
#
# *Hint:* Use `sklearn.model_selection.train_test_split`.

# %%
#[Answer Ex 15.3.1]
from sklearn.model_selection import train_test_split
sklearn.model_selection.train_test_split

X = df['reviewBody']
y = df['reviewRating_ratingValue']

X_train_dev, X_test, y_train_dev, y_test = train_test_split(X, y, test_size=0.5, random_state=0)

# %% [markdown]
# > **Ex 15.3.2:** Preproce the documents as in Ex 15.1.3. Then, initialize the `sklearn.feature_extraction.text.CountVectorizer`.
# The countvectorizer has many possible inputs: The important ones here are the tokenization function (use the one defined above, i.e. `tokenizer=tokenizer.tokenize`) and `ngram_range=(1,2)`. Finally, run the `.fit()` function with the train documents as input.

# %%
#[Answer Ex 15.3.2]

# %% [markdown]
# > **Ex 15.3.3:** Transform train and test documents to a sparse vector using the `transform` command on both the test and the train documents. Assign these to two variables, e.g. `X_train` and `X_test`. Afterwards, inspect the resulting dimensions of each input vector using the `.shape` function.

# %%
#[Answer Ex 15.3.3]

# %% [markdown]
# > **Ex 15.3.4:** Convert ratings to binary outcome. Here we make a decision to count ratings as positive if above 3 and otherwise negative. Define ***y_train*** and ***y_test*** as a binary variables expressing whether it is higher than 3 or not.

# %%
#[Answer Ex 15.3.4]

# %% [markdown]
# Now we are ready to train our model. We will use the penalized logistic regression which is widely used for training baseline in within natural language processing (NLP) - especially with a little twist see [Wang and Manning 2012](https://www.aclweb.org/anthology/P12-2018).
# As always we should we remember to do our parameter search using the training data only.
#
# > **Ex 15.3.5:** In this case we will do only a search over the penalizationterm C and, therefore, we can use the `sklearn.linear_model.LogisticRegressionCV()` which handles kfold-based parameter search directly. The function takes as arguments the range of values to be searched and the number of folds used for cross-validation.
#
# *Hint:* You can use a `LogisticRegressionCV()` with the arguments `Cs=np.linspace(0.1,2,10)`,`cv=10` and `verbose=2`. You can vary these arguments if you want.

# %%
# [Answer Ex 15.3.5]

# %% [markdown]
# > **Ex 15.3.6:** Report the performance of the classifier. You should report the accuracy. Additionally, you might want to report precision, recall, f1, AUC and roc-auc-curve.
#
# *Hint:* These measures can be computed using the `sklearn.metrics` package. You might want to define a function that takes your classifier and data as input and returns the metrics.

# %%
# [Answer Ex 15.3.6]

# %% [markdown]
# > **Ex 15.3.7:** Create a column in the dataframe applying the classifier to all documents.
# 1. First transform documents using vectorizer from before.
# 2. Get the predicted probability of a positive review: `clf.predict_proba(X)`. Note that you only need the second column - it predicts probabilities for both classes 0 and 1.

# %%
# [Answer Ex 15.3.7]

# %% [markdown]
# >**Ex 15.3.8 (BONUS):** Compute the correlation of the computed sentiment with the given rating for all three methods. Would you expect a positive or a negative correlation? Note that there are different categories describing the ratings' subjects (see the ***categories*** column). You can compute the correlation averaging the ratings and the sentiment scores over these categories.

# %%
# [Answer Ex 15.3.8 (BONUS)]
