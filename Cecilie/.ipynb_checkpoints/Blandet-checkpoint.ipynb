# %%
import names
import nltk

# %%
from nltk.corpus import names

nltk.download('names')
# Out:
# [nltk_data] Downloading package names to
# [nltk_data]     C:\Users\cecil\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\names.zip.
# True

# %%
names.fileids()
# Out:
# ['female.txt', 'male.txt']

# %%
namelist = ([(name, 'male') for name in names.words('male.txt')] + [(name, 'female') for name in names.words('female.txt')])

namelist
# Out:
# [('Aamir', 'male'),
#  ('Aaron', 'male'),
#  ('Abbey', 'male'),
#  ('Abbie', 'male'),
#  ('Abbot', 'male'),
#  ('Abbott', 'male'),
#  ('Abby', 'male'),
#  ('Abdel', 'male'),
#  ('Abdul', 'male'),
#  ('Abdulkarim', 'male'),
#  ('Abdullah', 'male'),
#  ('Abe', 'male'),
#  ('Abel', 'male'),
#  ('Abelard', 'male'),
#  ('Abner', 'male'),
#  ('Abraham', 'male'),
#  ('Abram', 'male'),
#  ('Ace', 'male'),
#  ('Adair', 'male'),
#  ('Adam', 'male'),
#  ('Adams', 'male'),
#  ('Addie', 'male'),
#  ('Adger', 'male'),
#  ('Aditya', 'male'),
#  ('Adlai', 'male'),
#  ('Adnan', 'male'),
#  ('Adolf', 'male'),
#  ('Adolfo', 'male'),
#  ('Adolph', 'male'),
#  ('Adolphe', 'male'),
#  ('Adolpho', 'male'),
#  ('Adolphus', 'male'),
#  ('Adrian', 'male'),
#  ('Adrick', 'male'),
#  ('Adrien', 'male'),
#  ('Agamemnon', 'male'),
#  ('Aguinaldo', 'male'),
#  ('Aguste', 'male'),
#  ('Agustin', 'male'),
#  ('Aharon', 'male'),
#  ('Ahmad', 'male'),
#  ('Ahmed', 'male'),
#  ('Ahmet', 'male'),
#  ('Ajai', 'male'),
#  ('Ajay', 'male'),
#  ('Al', 'male'),
#  ('Alaa', 'male'),
#  ('Alain', 'male'),
#  ('Alan', 'male'),
#  ('Alasdair', 'male'),
#  ('Alastair', 'male'),
#  ('Albatros', 'male'),
#  ('Albert', 'male'),
#  ('Alberto', 'male'),
#  ('Albrecht', 'male'),
#  ('Alden', 'male'),
#  ('Aldis', 'male'),
#  ('Aldo', 'male'),
#  ('Aldric', 'male'),
#  ('Aldrich', 'male'),
#  ('Aldus', 'male'),
#  ('Aldwin', 'male'),
#  ('Alec', 'male'),
#  ('Aleck', 'male'),
#  ('Alejandro', 'male'),
#  ('Aleks', 'male'),
#  ('Aleksandrs', 'male'),
#  ('Alessandro', 'male'),
#  ('Alex', 'male'),
#  ('Alexander', 'male'),
#  ('Alexei', 'male'),
#  ('Alexis', 'male'),
#  ('Alf', 'male'),
#  ('Alfie', 'male'),
#  ('Alfonse', 'male'),
#  ('Alfonso', 'male'),
#  ('Alfonzo', 'male'),
#  ('Alford', 'male'),
#  ('Alfred', 'male'),
#  ('Alfredo', 'male'),
#  ('Algernon', 'male'),
#  ('Ali', 'male'),
#  ('Alic', 'male'),
#  ('Alister', 'male'),
#  ('Alix', 'male'),
#  ('Allah', 'male'),
#  ('Allan', 'male'),
#  ('Allen', 'male'),
#  ('Alley', 'male'),
#  ('Allie', 'male'),
#  ('Allin', 'male'),
#  ('Allyn', 'male'),
#  ('Alonso', 'male'),
#  ('Alonzo', 'male'),
#  ('Aloysius', 'male'),
#  ('Alphonse', 'male'),
#  ('Alphonso', 'male'),
#  ('Alston', 'male'),
#  ('Alton', 'male'),
#  ('Alvin', 'male'),
#  ('Alwin', 'male'),
#  ('Amadeus', 'male'),
#  ('Ambros', 'male'),
#  ('Ambrose', 'male'),
#  ('Ambrosi', 'male'),
#  ('Ambrosio', 'male'),
#  ('Ambrosius', 'male'),
#  ('Amery', 'male'),
#  ('Amory', 'male'),
#  ('Amos', 'male'),
#  ('Anatol', 'male'),
#  ('Anatole', 'male'),
#  ('Anatollo', 'male'),
#  ('Anatoly', 'male'),
#  ('Anders', 'male'),
#  ('Andie', 'male'),
#  ('Andonis', 'male'),
#  ('Andre', 'male'),
#  ('Andrea', 'male'),
#  ('Andreas', 'male'),
#  ('Andrej', 'male'),
#  ('Andres', 'male'),
#  ('Andrew', 'male'),
#  ('Andrey', 'male'),
#  ('Andri', 'male'),
#  ('Andros', 'male'),
#  ('Andrus', 'male'),
#  ('Andrzej', 'male'),
#  ('Andy', 'male'),
#  ('Angel', 'male'),
#  ('Angelico', 'male'),
#  ('Angelo', 'male'),
#  ('Angie', 'male'),
#  ('Angus', 'male'),
#  ('Ansel', 'male'),
#  ('Ansell', 'male'),
#  ('Anselm', 'male'),
#  ('Anson', 'male'),
#  ('Anthony', 'male'),
#  ('Antin', 'male'),
#  ('Antoine', 'male'),
#  ('Anton', 'male'),
#  ('Antone', 'male'),
#  ('Antoni', 'male'),
#  ('Antonin', 'male'),
#  ('Antonino', 'male'),
#  ('Antonio', 'male'),
#  ('Antonius', 'male'),
#  ('Antony', 'male'),
#  ('Anurag', 'male'),
#  ('Apollo', 'male'),
#  ('Apostolos', 'male'),
#  ('Aram', 'male'),
#  ('Archibald', 'male'),
#  ('Archibold', 'male'),
#  ('Archie', 'male'),
#  ('Archon', 'male'),
#  ('Archy', 'male'),
#  ('Arel', 'male'),
#  ('Ari', 'male'),
#  ('Arie', 'male'),
#  ('Ariel', 'male'),
#  ('Aristotle', 'male'),
#  ('Arlo', 'male'),
#  ('Armand', 'male'),
#  ('Armando', 'male'),
#  ('Armond', 'male'),
#  ('Armstrong', 'male'),
#  ('Arne', 'male'),
#  ('Arnie', 'male'),
#  ('Arnold', 'male'),
#  ('Arnoldo', 'male'),
#  ('Aron', 'male'),
#  ('Arron', 'male'),
#  ('Art', 'male'),
#  ('Arther', 'male'),
#  ('Arthur', 'male'),
#  ('Artie', 'male'),
#  ('Artur', 'male'),
#  ('Arturo', 'male'),
#  ('Arvie', 'male'),
#  ('Arvin', 'male'),
#  ('Arvind', 'male'),
#  ('Arvy', 'male'),
#  ('Ash', 'male'),
#  ('Ashby', 'male'),
#  ('Ashish', 'male'),
#  ('Ashley', 'male'),
#  ('Ashton', 'male'),
#  ('Aub', 'male'),
#  ('Aube', 'male'),
#  ('Aubert', 'male'),
#  ('Aubrey', 'male'),
#  ('Augie', 'male'),
#  ('August', 'male'),
#  ('Augustin', 'male'),
#  ('Augustine', 'male'),
#  ('Augusto', 'male'),
#  ('Augustus', 'male'),
#  ('Austen', 'male'),
#  ('Austin', 'male'),
#  ('Ave', 'male'),
#  ('Averell', 'male'),
#  ('Averil', 'male'),
#  ('Averill', 'male'),
#  ('Avery', 'male'),
#  ('Avi', 'male'),
#  ('Avraham', 'male'),
#  ('Avram', 'male'),
#  ('Avrom', 'male'),
#  ('Axel', 'male'),
#  ('Aylmer', 'male'),
#  ('Aziz', 'male'),
#  ('Bailey', 'male'),
#  ('Bailie', 'male'),
#  ('Baillie', 'male'),
#  ('Baily', 'male'),
#  ('Baird', 'male'),
#  ('Baldwin', 'male'),
#  ('Bancroft', 'male'),
#  ('Barbabas', 'male'),
#  ('Barclay', 'male'),
#  ('Bard', 'male'),
#  ('Barde', 'male'),
#  ('Barn', 'male'),
#  ('Barnabas', 'male'),
#  ('Barnabe', 'male'),
#  ('Barnaby', 'male'),
#  ('Barnard', 'male'),
#  ('Barnebas', 'male'),
#  ('Barnett', 'male'),
#  ('Barney', 'male'),
#  ('Barnie', 'male'),
#  ('Barny', 'male'),
#  ('Baron', 'male'),
#  ('Barr', 'male'),
#  ('Barret', 'male'),
#  ('Barrett', 'male'),
#  ('Barri', 'male'),
#  ('Barrie', 'male'),
#  ('Barris', 'male'),
#  ('Barron', 'male'),
#  ('Barry', 'male'),
#  ('Bart', 'male'),
#  ('Bartel', 'male'),
#  ('Barth', 'male'),
#  ('Barthel', 'male'),
#  ('Bartholemy', 'male'),
#  ('Bartholomeo', 'male'),
#  ('Bartholomeus', 'male'),
#  ('Bartholomew', 'male'),
#  ('Bartie', 'male'),
#  ('Bartlet', 'male'),
#  ('Bartlett', 'male'),
#  ('Bartolemo', 'male'),
#  ('Bartolomei', 'male'),
#  ('Bartolomeo', 'male'),
#  ('Barton', 'male'),
#  ('Barty', 'male'),
#  ('Bary', 'male'),
#  ('Basil', 'male'),
#  ('Batholomew', 'male'),
#  ('Baxter', 'male'),
#  ('Bay', 'male'),
#  ('Bayard', 'male'),
#  ('Beale', 'male'),
#  ('Bealle', 'male'),
#  ('Bear', 'male'),
#  ('Bearnard', 'male'),
#  ('Beau', 'male'),
#  ('Beaufort', 'male'),
#  ('Beauregard', 'male'),
#  ('Beck', 'male'),
#  ('Bela', 'male'),
#  ('Ben', 'male'),
#  ('Benedict', 'male'),
#  ('Bengt', 'male'),
#  ('Benito', 'male'),
#  ('Benjamen', 'male'),
#  ('Benjamin', 'male'),
#  ('Benji', 'male'),
#  ('Benjie', 'male'),
#  ('Benjy', 'male'),
#  ('Benn', 'male'),
#  ('Bennet', 'male'),
#  ('Bennett', 'male'),
#  ('Bennie', 'male'),
#  ('Benny', 'male'),
#  ('Benson', 'male'),
#  ('Bentley', 'male'),
#  ('Benton', 'male'),
#  ('Beowulf', 'male'),
#  ('Berchtold', 'male'),
#  ('Berk', 'male'),
#  ('Berke', 'male'),
#  ('Berkeley', 'male'),
#  ('Berkie', 'male'),
#  ('Berkley', 'male'),
#  ('Bernard', 'male'),
#  ('Bernardo', 'male'),
#  ('Bernd', 'male'),
#  ('Bernhard', 'male'),
#  ('Bernie', 'male'),
#  ('Bert', 'male'),
#  ('Bertie', 'male'),
#  ('Bertram', 'male'),
#  ('Bertrand', 'male'),
#  ('Bharat', 'male'),
#  ('Biff', 'male'),
#  ('Bill', 'male'),
#  ('Billie', 'male'),
#  ('Billy', 'male'),
#  ('Bing', 'male'),
#  ('Binky', 'male'),
#  ('Bishop', 'male'),
#  ('Bjorn', 'male'),
#  ('Bjorne', 'male'),
#  ('Blaine', 'male'),
#  ('Blair', 'male'),
#  ('Blake', 'male'),
#  ('Blare', 'male'),
#  ('Blayne', 'male'),
#  ('Bo', 'male'),
#  ('Bob', 'male'),
#  ('Bobbie', 'male'),
#  ('Bobby', 'male'),
#  ('Bogart', 'male'),
#  ('Bogdan', 'male'),
#  ('Boniface', 'male'),
#  ('Boris', 'male'),
#  ('Boyce', 'male'),
#  ('Boyd', 'male'),
#  ('Brad', 'male'),
#  ('Braden', 'male'),
#  ('Bradford', 'male'),
#  ('Bradley', 'male'),
#  ('Bradly', 'male'),
#  ('Brady', 'male'),
#  ('Brandon', 'male'),
#  ('Brandy', 'male'),
#  ('Brant', 'male'),
#  ('Brendan', 'male'),
#  ('Brent', 'male'),
#  ('Bret', 'male'),
#  ('Brett', 'male'),
#  ('Brewer', 'male'),
#  ('Brewster', 'male'),
#  ('Brian', 'male'),
#  ('Brice', 'male'),
#  ('Briggs', 'male'),
#  ('Brinkley', 'male'),
#  ('Britt', 'male'),
#  ('Brock', 'male'),
#  ('Broddie', 'male'),
#  ('Broddy', 'male'),
#  ('Broderic', 'male'),
#  ('Broderick', 'male'),
#  ('Brodie', 'male'),
#  ('Brody', 'male'),
#  ('Bronson', 'male'),
#  ('Brook', 'male'),
#  ('Brooke', 'male'),
#  ('Brooks', 'male'),
#  ('Bruce', 'male'),
#  ('Bruno', 'male'),
#  ('Bryan', 'male'),
#  ('Bryant', 'male'),
#  ('Bryce', 'male'),
#  ('Bryn', 'male'),
#  ('Bryon', 'male'),
#  ('Bubba', 'male'),
#  ('Buck', 'male'),
#  ('Bucky', 'male'),
#  ('Bud', 'male'),
#  ('Buddy', 'male'),
#  ('Burgess', 'male'),
#  ('Burke', 'male'),
#  ('Burl', 'male'),
#  ('Burnaby', 'male'),
#  ('Burt', 'male'),
#  ('Burton', 'male'),
#  ('Buster', 'male'),
#  ('Butch', 'male'),
#  ('Butler', 'male'),
#  ('Byram', 'male'),
#  ('Byron', 'male'),
#  ('Caesar', 'male'),
#  ('Cain', 'male'),
#  ('Cal', 'male'),
#  ('Caldwell', 'male'),
#  ('Caleb', 'male'),
#  ('Calhoun', 'male'),
#  ('Calvin', 'male'),
#  ('Cam', 'male'),
#  ('Cameron', 'male'),
#  ('Cammy', 'male'),
#  ('Carey', 'male'),
#  ('Carl', 'male'),
#  ('Carleigh', 'male'),
#  ('Carlie', 'male'),
#  ('Carlin', 'male'),
#  ('Carlo', 'male'),
#  ('Carlos', 'male'),
#  ('Carlton', 'male'),
#  ('Carlyle', 'male'),
#  ('Carmine', 'male'),
#  ('Carroll', 'male'),
#  ('Carson', 'male'),
#  ('Carsten', 'male'),
#  ('Carter', 'male'),
#  ('Cary', 'male'),
#  ('Caryl', 'male'),
#  ('Case', 'male'),
#  ('Casey', 'male'),
#  ('Caspar', 'male'),
#  ('Casper', 'male'),
#  ('Cass', 'male'),
#  ('Cat', 'male'),
#  ('Cecil', 'male'),
#  ('Cesar', 'male'),
#  ('Chad', 'male'),
#  ('Chadd', 'male'),
#  ('Chaddie', 'male'),
#  ('Chaddy', 'male'),
#  ('Chadwick', 'male'),
#  ('Chaim', 'male'),
#  ('Chalmers', 'male'),
#  ('Chan', 'male'),
#  ('Chance', 'male'),
#  ('Chancey', 'male'),
#  ('Chanderjit', 'male'),
#  ('Chandler', 'male'),
#  ('Chane', 'male'),
#  ('Chariot', 'male'),
#  ('Charles', 'male'),
#  ('Charleton', 'male'),
#  ('Charley', 'male'),
#  ('Charlie', 'male'),
#  ('Charlton', 'male'),
#  ('Chas', 'male'),
#  ('Chase', 'male'),
#  ('Chaunce', 'male'),
#  ('Chauncey', 'male'),
#  ('Che', 'male'),
#  ('Chelton', 'male'),
#  ('Chen', 'male'),
#  ('Chester', 'male'),
#  ('Cheston', 'male'),
#  ('Chet', 'male'),
#  ('Chev', 'male'),
#  ('Chevalier', 'male'),
#  ('Chevy', 'male'),
#  ('Chip', 'male'),
#  ('Chris', 'male'),
#  ('Chrissy', 'male'),
#  ('Christ', 'male'),
#  ('Christian', 'male'),
#  ('Christiano', 'male'),
#  ('Christie', 'male'),
#  ('Christof', 'male'),
#  ('Christofer', 'male'),
#  ('Christoph', 'male'),
#  ('Christophe', 'male'),
#  ('Christopher', 'male'),
#  ('Christorpher', 'male'),
#  ('Christos', 'male'),
#  ('Christy', 'male'),
#  ('Chrisy', 'male'),
#  ('Chuck', 'male'),
#  ('Churchill', 'male'),
#  ('Clair', 'male'),
#  ('Claire', 'male'),
#  ('Clancy', 'male'),
#  ('Clarance', 'male'),
#  ('Clare', 'male'),
#  ('Clarence', 'male'),
#  ('Clark', 'male'),
#  ('Clarke', 'male'),
#  ('Claude', 'male'),
#  ('Claudio', 'male'),
#  ('Claudius', 'male'),
#  ('Claus', 'male'),
#  ('Clay', 'male'),
#  ('Clayborn', 'male'),
#  ('Clayborne', 'male'),
#  ('Claybourne', 'male'),
#  ('Clayton', 'male'),
#  ('Cleland', 'male'),
#  ('Clem', 'male'),
#  ('Clemens', 'male'),
#  ('Clement', 'male'),
#  ('Clemente', 'male'),
#  ('Clemmie', 'male'),
#  ('Cletus', 'male'),
#  ('Cleveland', 'male'),
#  ('Cliff', 'male'),
#  ('Clifford', 'male'),
#  ('Clifton', 'male'),
#  ('Clint', 'male'),
#  ('Clinten', 'male'),
#  ('Clinton', 'male'),
#  ('Clive', 'male'),
#  ('Clyde', 'male'),
#  ('Cob', 'male'),
#  ('Cobb', 'male'),
#  ('Cobbie', 'male'),
#  ('Cobby', 'male'),
#  ('Cody', 'male'),
#  ('Colbert', 'male'),
#  ('Cole', 'male'),
#  ('Coleman', 'male'),
#  ('Colin', 'male'),
#  ('Collin', 'male'),
#  ('Collins', 'male'),
#  ('Conan', 'male'),
#  ('Connie', 'male'),
#  ('Connolly', 'male'),
#  ('Connor', 'male'),
#  ('Conrad', 'male'),
#  ('Conroy', 'male'),
#  ('Constantin', 'male'),
#  ('Constantine', 'male'),
#  ('Constantinos', 'male'),
#  ('Conway', 'male'),
#  ('Cooper', 'male'),
#  ('Corbin', 'male'),
#  ('Corby', 'male'),
#  ('Corey', 'male'),
#  ('Corky', 'male'),
#  ('Cornelius', 'male'),
#  ('Cornellis', 'male'),
#  ('Corrie', 'male'),
#  ('Cortese', 'male'),
#  ('Corwin', 'male'),
#  ('Cory', 'male'),
#  ('Cosmo', 'male'),
#  ('Costa', 'male'),
#  ('Courtney', 'male'),
#  ('Craig', 'male'),
#  ('Crawford', 'male'),
#  ('Creighton', 'male'),
#  ('Cris', 'male'),
#  ('Cristopher', 'male'),
#  ('Curt', 'male'),
#  ('Curtice', 'male'),
#  ('Curtis', 'male'),
#  ('Cy', 'male'),
#  ('Cyril', 'male'),
#  ('Cyrill', 'male'),
#  ('Cyrille', 'male'),
#  ('Cyrillus', 'male'),
#  ('Cyrus', 'male'),
#  ('Dabney', 'male'),
#  ('Daffy', 'male'),
#  ('Dale', 'male'),
#  ('Dallas', 'male'),
#  ('Dalton', 'male'),
#  ('Damian', 'male'),
#  ('Damien', 'male'),
#  ('Damon', 'male'),
#  ('Dan', 'male'),
#  ('Dana', 'male'),
#  ('Dane', 'male'),
#  ('Dani', 'male'),
#  ('Danie', 'male'),
#  ('Daniel', 'male'),
#  ('Dannie', 'male'),
#  ('Danny', 'male'),
#  ('Dante', 'male'),
#  ('Darby', 'male'),
#  ('Darcy', 'male'),
#  ('Daren', 'male'),
#  ('Darian', 'male'),
#  ('Darien', 'male'),
#  ('Darin', 'male'),
#  ('Dario', 'male'),
#  ('Darius', 'male'),
#  ('Darrel', 'male'),
#  ('Darrell', 'male'),
#  ('Darren', 'male'),
#  ('Darrick', 'male'),
#  ('Darrin', 'male'),
#  ('Darryl', 'male'),
#  ('Darth', 'male'),
#  ('Darwin', 'male'),
#  ('Daryl', 'male'),
#  ('Daryle', 'male'),
#  ('Dave', 'male'),
#  ('Davey', 'male'),
#  ('David', 'male'),
#  ('Davidde', 'male'),
#  ('Davide', 'male'),
#  ('Davidson', 'male'),
#  ('Davie', 'male'),
#  ('Davin', 'male'),
#  ('Davis', 'male'),
#  ('Davon', 'male'),
#  ('Davoud', 'male'),
#  ('Davy', 'male'),
#  ('Dawson', 'male'),
#  ('Dean', 'male'),
#  ('Deane', 'male'),
#  ('Del', 'male'),
#  ('Delbert', 'male'),
#  ('Dell', 'male'),
#  ('Delmar', 'male'),
#  ('Demetre', 'male'),
#  ('Demetri', 'male'),
#  ('Demetris', 'male'),
#  ('Demetrius', 'male'),
#  ('Demosthenis', 'male'),
#  ('Denis', 'male'),
#  ('Dennie', 'male'),
#  ('Dennis', 'male'),
#  ('Denny', 'male'),
#  ('Derby', 'male'),
#  ('Derek', 'male'),
#  ('Derick', 'male'),
#  ('Derk', 'male'),
#  ('Derrek', 'male'),
#  ('Derrick', 'male'),
#  ('Derrin', 'male'),
#  ('Derrol', 'male'),
#  ('Derron', 'male'),
#  ('Deryl', 'male'),
#  ('Desmond', 'male'),
#  ('Desmund', 'male'),
#  ('Devin', 'male'),
#  ('Devon', 'male'),
#  ('Dewey', 'male'),
#  ('Dewitt', 'male'),
#  ('Dexter', 'male'),
#  ('Dick', 'male'),
#  ('Dickey', 'male'),
#  ('Dickie', 'male'),
#  ('Diego', 'male'),
#  ('Dieter', 'male'),
#  ('Dietrich', 'male'),
#  ('Dillon', 'male'),
#  ('Dimitri', 'male'),
#  ('Dimitrios', 'male'),
#  ('Dimitris', 'male'),
#  ('Dimitrou', 'male'),
#  ('Dimitry', 'male'),
#  ('Dino', 'male'),
#  ('Dion', 'male'),
#  ('Dionis', 'male'),
#  ('Dionysus', 'male'),
#  ('Dirk', 'male'),
#  ('Dmitri', 'male'),
#  ('Dom', 'male'),
#  ('Domenic', 'male'),
#  ('Domenico', 'male'),
#  ('Dominic', 'male'),
#  ('Dominick', 'male'),
#  ('Dominique', 'male'),
#  ('Don', 'male'),
#  ('Donal', 'male'),
#  ('Donald', 'male'),
#  ('Donn', 'male'),
#  ('Donnie', 'male'),
#  ('Donny', 'male'),
#  ('Donovan', 'male'),
#  ('Dorian', 'male'),
#  ('Dory', 'male'),
#  ('Doug', 'male'),
#  ('Douggie', 'male'),
#  ('Dougie', 'male'),
#  ('Douglas', 'male'),
#  ('Douglass', 'male'),
#  ('Douglis', 'male'),
#  ('Dov', 'male'),
#  ('Doyle', 'male'),
#  ('Drake', 'male'),
#  ('Drew', 'male'),
#  ('Dru', 'male'),
#  ('Dryke', 'male'),
#  ('Duane', 'male'),
#  ('Dudley', 'male'),
#  ('Duffie', 'male'),
#  ('Duffy', 'male'),
#  ('Dugan', 'male'),
#  ('Duke', 'male'),
#  ('Dunc', 'male'),
#  ('Duncan', 'male'),
#  ('Dunstan', 'male'),
#  ('Durand', 'male'),
#  ('Durant', 'male'),
#  ('Durante', 'male'),
#  ('Durward', 'male'),
#  ('Dustin', 'male'),
#  ('Dwain', 'male'),
#  ('Dwaine', 'male'),
#  ('Dwane', 'male'),
#  ('Dwayne', 'male'),
#  ('Dwight', 'male'),
#  ('Dylan', 'male'),
#  ('Dyson', 'male'),
#  ('Earl', 'male'),
#  ('Earle', 'male'),
#  ('Easton', 'male'),
#  ('Eben', 'male'),
#  ('Ebeneser', 'male'),
#  ('Ebenezer', 'male'),
#  ('Eberhard', 'male'),
#  ('Ed', 'male'),
#  ('Eddie', 'male'),
#  ('Eddy', 'male'),
#  ('Edgar', 'male'),
#  ('Edgardo', 'male'),
#  ('Edie', 'male'),
#  ('Edmond', 'male'),
#  ('Edmund', 'male'),
#  ('Edouard', 'male'),
#  ('Edsel', 'male'),
#  ('Eduard', 'male'),
#  ('Eduardo', 'male'),
#  ('Edward', 'male'),
#  ('Edwin', 'male'),
#  ('Efram', 'male'),
#  ('Egbert', 'male'),
#  ('Ehud', 'male'),
#  ('Elbert', 'male'),
#  ('Elden', 'male'),
#  ('Eldon', 'male'),
#  ('Eli', 'male'),
#  ('Elias', 'male'),
#  ('Elihu', 'male'),
#  ('Elijah', 'male'),
#  ('Eliot', 'male'),
#  ('Eliott', 'male'),
#  ('Elisha', 'male'),
#  ('Elliot', 'male'),
#  ('Elliott', 'male'),
#  ('Ellis', 'male'),
#  ('Ellsworth', 'male'),
#  ('Ellwood', 'male'),
#  ('Elmer', 'male'),
#  ('Elmore', 'male'),
#  ('Elnar', 'male'),
#  ('Elric', 'male'),
#  ('Elroy', 'male'),
#  ('Elton', 'male'),
#  ('Elvin', 'male'),
#  ('Elvis', 'male'),
#  ('Elwin', 'male'),
#  ('Elwood', 'male'),
#  ('Elwyn', 'male'),
#  ('Ely', 'male'),
#  ('Emanuel', 'male'),
#  ('Emerson', 'male'),
#  ('Emery', 'male'),
#  ('Emil', 'male'),
#  ('Emile', 'male'),
#  ('Emilio', 'male'),
#  ('Emmanuel', 'male'),
#  ('Emmery', 'male'),
#  ('Emmet', 'male'),
#  ('Emmett', 'male'),
#  ('Emmit', 'male'),
#  ('Emmott', 'male'),
#  ('Emmy', 'male'),
#  ('Emory', 'male'),
#  ('Ender', 'male'),
#  ('Engelbart', 'male'),
#  ('Engelbert', 'male'),
#  ('Englebart', 'male'),
#  ('Englebert', 'male'),
#  ('Enoch', 'male'),
#  ('Enrico', 'male'),
#  ('Enrique', 'male'),
#  ('Ephraim', 'male'),
#  ('Ephram', 'male'),
#  ('Ephrayim', 'male'),
#  ('Ephrem', 'male'),
#  ('Er', 'male'),
#  ('Erasmus', 'male'),
#  ('Erastus', 'male'),
#  ('Erek', 'male'),
#  ('Erhard', 'male'),
#  ('Erhart', 'male'),
#  ('Eric', 'male'),
#  ('Erich', 'male'),
#  ('Erick', 'male'),
#  ('Erik', 'male'),
#  ('Erin', 'male'),
#  ('Erl', 'male'),
#  ('Ernest', 'male'),
#  ('Ernesto', 'male'),
#  ('Ernie', 'male'),
#  ('Ernst', 'male'),
#  ('Erny', 'male'),
#  ('Errol', 'male'),
#  ('Ervin', 'male'),
#  ('Erwin', 'male'),
#  ('Esau', 'male'),
#  ('Esme', 'male'),
#  ('Esteban', 'male'),
#  ('Ethan', 'male'),
#  ('Ethelbert', 'male'),
#  ('Ethelred', 'male'),
#  ('Etienne', 'male'),
#  ('Euclid', 'male'),
#  ('Eugen', 'male'),
#  ('Eugene', 'male'),
#  ('Eustace', 'male'),
#  ('Ev', 'male'),
#  ('Evan', 'male'),
#  ('Evelyn', 'male'),
#  ('Everard', 'male'),
#  ('Everett', 'male'),
#  ('Ewan', 'male'),
#  ('Ewart', 'male'),
#  ('Ez', 'male'),
#  ('Ezechiel', 'male'),
#  ('Ezekiel', 'male'),
#  ('Ezra', 'male'),
#  ('Fabian', 'male'),
#  ('Fabio', 'male'),
#  ('Fairfax', 'male'),
#  ('Farley', 'male'),
#  ('Fazeel', 'male'),
#  ('Federico', 'male'),
#  ('Felice', 'male'),
#  ('Felicio', 'male'),
#  ('Felipe', 'male'),
#  ('Felix', 'male'),
#  ('Ferd', 'male'),
#  ('Ferdie', 'male'),
#  ('Ferdinand', 'male'),
#  ('Ferdy', 'male'),
#  ('Fergus', 'male'),
#  ('Ferguson', 'male'),
#  ('Ferinand', 'male'),
#  ('Fernando', 'male'),
#  ('Fidel', 'male'),
#  ('Filbert', 'male'),
#  ('Filip', 'male'),
#  ('Filipe', 'male'),
#  ('Filmore', 'male'),
#  ('Finley', 'male'),
#  ('Finn', 'male'),
#  ('Fitz', 'male'),
#  ('Fitzgerald', 'male'),
#  ('Flem', 'male'),
#  ('Fleming', 'male'),
#  ('Flemming', 'male'),
#  ('Fletch', 'male'),
#  ('Fletcher', 'male'),
#  ('Flin', 'male'),
#  ('Flinn', 'male'),
#  ('Flint', 'male'),
#  ('Flipper', 'male'),
#  ('Florian', 'male'),
#  ('Floyd', 'male'),
#  ('Flynn', 'male'),
#  ('Fons', 'male'),
#  ('Fonsie', 'male'),
#  ('Fonz', 'male'),
#  ('Fonzie', 'male'),
#  ('Forbes', 'male'),
#  ('Ford', 'male'),
#  ('Forest', 'male'),
#  ('Forester', 'male'),
#  ('Forrest', 'male'),
#  ('Forrester', 'male'),
#  ('Forster', 'male'),
#  ('Foster', 'male'),
#  ('Fowler', 'male'),
#  ('Fox', 'male'),
#  ('Fran', 'male'),
#  ('Francesco', 'male'),
#  ('Francis', 'male'),
#  ('Francisco', 'male'),
#  ('Francois', 'male'),
#  ('Frank', 'male'),
#  ('Frankie', 'male'),
#  ('Franklin', 'male'),
#  ('Franklyn', 'male'),
#  ('Franky', 'male'),
#  ('Frans', 'male'),
#  ('Franz', 'male'),
#  ('Fraser', 'male'),
#  ('Frazier', 'male'),
#  ('Fred', 'male'),
#  ('Freddie', 'male'),
#  ('Freddy', 'male'),
#  ('Frederic', 'male'),
#  ('Frederich', 'male'),
#  ('Frederick', 'male'),
#  ('Frederico', 'male'),
#  ('Frederik', 'male'),
#  ('Fredric', 'male'),
#  ('Fredrick', 'male'),
#  ('Freeman', 'male'),
#  ('Freemon', 'male'),
#  ('Fremont', 'male'),
#  ('French', 'male'),
#  ('Friedric', 'male'),
#  ('Friedrich', 'male'),
#  ('Friedrick', 'male'),
#  ('Fritz', 'male'),
#  ('Fulton', 'male'),
#  ('Fyodor', 'male'),
#  ('Gabe', 'male'),
#  ('Gabriel', 'male'),
#  ('Gabriele', 'male'),
#  ('Gabriell', 'male'),
#  ('Gabriello', 'male'),
#  ('Gail', 'male'),
#  ('Gale', 'male'),
#  ('Galen', 'male'),
#  ('Gallagher', 'male'),
#  ('Gamaliel', 'male'),
#  ('Garcia', 'male'),
#  ('Garcon', 'male'),
#  ('Gardener', 'male'),
#  ('Gardiner', 'male'),
#  ('Gardner', 'male'),
#  ('Garey', 'male'),
#  ('Garfield', 'male'),
#  ('Garfinkel', 'male'),
#  ('Garold', 'male'),
#  ('Garp', 'male'),
#  ('Garret', 'male'),
#  ('Garrett', 'male'),
#  ('Garrot', 'male'),
#  ('Garrott', 'male'),
#  ('Garry', 'male'),
#  ('Garth', 'male'),
#  ('Garv', 'male'),
#  ('Garvey', 'male'),
#  ('Garvin', 'male'),
#  ('Garvy', 'male'),
#  ('Garwin', 'male'),
#  ('Garwood', 'male'),
#  ('Gary', 'male'),
#  ('Gaspar', 'male'),
#  ('Gasper', 'male'),
#  ('Gaston', 'male'),
#  ('Gav', 'male'),
#  ('Gaven', 'male'),
#  ('Gavin', 'male'),
#  ('Gavriel', 'male'),
#  ('Gay', 'male'),
#  ('Gayle', 'male'),
#  ('Gearard', 'male'),
#  ('Gene', 'male'),
#  ('Geo', 'male'),
#  ('Geof', 'male'),
#  ('Geoff', 'male'),
#  ('Geoffrey', 'male'),
#  ('Geoffry', 'male'),
#  ('Georg', 'male'),
#  ('George', 'male'),
#  ('Georges', 'male'),
#  ('Georgia', 'male'),
#  ('Georgie', 'male'),
#  ('Georgy', 'male'),
#  ('Gerald', 'male'),
#  ('Geraldo', 'male'),
#  ('Gerard', 'male'),
#  ('Gere', 'male'),
#  ('Gerhard', 'male'),
#  ('Gerhardt', 'male'),
#  ('Geri', 'male'),
#  ('Germaine', 'male'),
#  ('Gerold', 'male'),
#  ('Gerome', 'male'),
#  ('Gerrard', 'male'),
#  ('Gerri', 'male'),
#  ('Gerrit', 'male'),
#  ('Gerry', 'male'),
#  ('Gershom', 'male'),
#  ('Gershon', 'male'),
#  ('Giacomo', 'male'),
#  ('Gian', 'male'),
#  ('Giancarlo', 'male'),
#  ('Giavani', 'male'),
#  ('Gibb', 'male'),
#  ('Gideon', 'male'),
#  ('Giff', 'male'),
#  ('Giffard', 'male'),
#  ('Giffer', 'male'),
#  ('Giffie', 'male'),
#  ('Gifford', 'male'),
#  ('Giffy', 'male'),
#  ('Gil', 'male'),
#  ('Gilbert', 'male'),
#  ('Gilberto', 'male'),
#  ('Gilburt', 'male'),
#  ('Giles', 'male'),
#  ('Gill', 'male'),
#  ('Gilles', 'male'),
#  ('Ginger', 'male'),
#  ('Gino', 'male'),
#  ('Giordano', 'male'),
#  ('Giorgi', 'male'),
#  ('Giorgio', 'male'),
#  ('Giovanne', 'male'),
#  ...]

# %% [markdown]
# # Work with the movies start from here

# %%
import scraping_class
logfile = 'log.csv'## name your log file.
connector = scraping_class.Connector(logfile)

# %%
#Defining url, the call and parsing
from bs4 import BeautifulSoup
import requests
url = 'https://www.imdb.com/search/keyword/?ref_=kw_ref_typ&sort=moviemeter%2Casc&mode=detail&page=1&title_type=movie&fbclid=IwAR3AAeVD_whYi1AwPsSGdYsgH8FnupVrBhImRFD__GL3wdHegJwcxrUsfyc'
response,callid = connector.get(url,'Exam')
html = response.text
soup = BeautifulSoup(html,'lxml')

#Here we define what node we are looking at
h3_node = soup.find('h3') # find table node with specific attribute

h3_node
# Out:
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">1.</span>
# <a href="/title/tt7131622/">Once Upon a Time... in Hollywood</a>
# <span class="lister-item-year text-muted unbold">(2019)</span>
# </h3>

# %%
#This is used to extract the names of the movies

headline = soup.find('h3') # search for the first headline: h1 tag. 
name = headline['class'][0].strip() # use the class attribute name as column name.
value = headline.text.strip() # extract text using build in method.
#print(name,':',value)
value.split('\n')[1]
# Out:
# 'Once Upon a Time... in Hollywood'

# %%
# Loop it through 
movielist= []

for v in range(1, 3):
    url1 = 'https://www.imdb.com/search/keyword/?ref_=kw_ref_typ&sort=moviemeter%2Casc&mode=detail&page={}&title_type=movie&fbclid=IwAR3AAeVD_whYi1AwPsSGdYsgH8FnupVrBhImRFD__GL3wdHegJwcxrUsfyc'.format(v)
    call = 'Exam, KU{}'.format(v)
    response,callid = connector.get(url1, call)
    html = response.text
    soup = BeautifulSoup(html,'lxml')
    
    for i in range(50):
        headline_i = soup.findAll('h3')[i] # search for the first headline: h1 tag. 
        #name = headline_i['class'][0].strip() # use the class attribute name as column name.
        value = headline_i.text.strip() # extract text using build in method.
        film = value.split('\n')[1]
        movielist.append(film)
    
movielist
# Out:
# ['Once Upon a Time... in Hollywood',
#  'Scary Stories to Tell in the Dark',
#  'Fast & Furious: Hobbs & Shaw',
#  'Little Women',
#  'Avengers: Endgame',
#  'Løvernes konge',
#  'Last Christmas',
#  'Parasite',
#  'Good Boys',
#  'Aladdin',
#  'Dora and the Lost City of Gold',
#  'It del 2',
#  'The Hunt',
#  'Aquaman',
#  'Godzilla II: King of the Monsters',
#  'Dolemite Is My Name',
#  'The Art of Racing in the Rain',
#  'Spider-Man: Far from Home',
#  'Brightburn',
#  'The Peanut Butter Falcon',
#  'The Kitchen',
#  'Operation Brothers',
#  'Nomis',
#  'Alita: Battle Angel',
#  'Joker',
#  'Midsommar',
#  'Ready or Not',
#  '47 Meters Down: Uncaged',
#  'Rocketman',
#  'John Wick 3: Parabellum',
#  'Shazam!',
#  'Blinded by the Light',
#  'Angry Birds 2 - Filmen',
#  'Long Shot',
#  'Spider-Man: Into the Spider-Verse',
#  'The Hustle',
#  'Thor: Love and Thunder',
#  'Inglourious Basterds',
#  'Pulp Fiction',
#  'Toy Story 4',
#  'Pokémon Detective Pikachu',
#  'Angel Has Fallen',
#  'Kæledyrenes hemmelige liv 2',
#  'Annabelle Comes Home',
#  "Where'd You Go, Bernadette",
#  'Ma',
#  'Rambo: Last Blood',
#  'Terminator: Dark Fate',
#  'Light of My Life',
#  'Hellboy',
#  'Smerte og ære',
#  'It',
#  'Otherhood',
#  'Shang-Chi and the Legend of the Ten Rings',
#  'Now and Then',
#  'Star Wars: The Rise of Skywalker',
#  'A Hidden Life',
#  'Bohemian Rhapsody',
#  'After',
#  'Captain Marvel',
#  'The Hateful Eight',
#  'Batla House',
#  'Crawl',
#  'Avengers: Infinity War',
#  'Driven',
#  'Us',
#  'Suicide Squad',
#  'The Irishman',
#  'Sextuplets',
#  'The Lion King',
#  'Hustlers',
#  'Familien Addams',
#  '1917',
#  'Yesterday',
#  'The Farewell',
#  'Ondskabens hus',
#  'Fantastiske skabninger: Grindelwalds forbrydelser',
#  'Håndlangerne',
#  'The Lighthouse',
#  'Downton Abbey',
#  'The Wolf of Wall Street',
#  'The Favourite',
#  "A Dog's Journey",
#  'A Star Is Born',
#  'Jackie Brown',
#  'Honey Boy',
#  'The New Mutants',
#  'Ad Astra',
#  'Dommedag nu',
#  'Wonder Woman 1984',
#  'Pigebørn',
#  'En verden udenfor',
#  'A Simple Favor',
#  'Django Unchained',
#  'Hello, Love, Goodbye',
#  'Men in Black: International',
#  'Godfather',
#  'The Goldfinch',
#  'Thor: Ragnarok',
#  'Nekrotronic']

# %%
#Extract the year (WORKS)
#Look at the years for the movies and plot them

year_list= []

for v in range(1, 2):
    #url1 = 'https://www.imdb.com/search/keyword/?ref_=kw_nxt&mode=detail&page={}&title_type=movie&fbclid=IwAR3AAeVD_whYi1AwPsSGdYsgH8FnupVrBhImRFD__GL3wdHegJwcxrUsfyc&sort=num_votes,desc'.format{v}
    url1 = 'https://www.imdb.com/search/keyword/?ref_=kw_nxt&mode=detail&page={}&title_type=movie&fbclid=IwAR3AAeVD_whYi1AwPsSGdYsgH8FnupVrBhImRFD__GL3wdHegJwcxrUsfyc&sort=num_votes,desc'.format(v)
    call = 'Exam, KU{}'.format(v)
    response,callid = connector.get(url1, call)
    html = response.text
    soup = BeautifulSoup(html,'lxml')
    
    for i in range(50):
        headline_i = soup.findAll('h3')[i] # search for the first headline: h1 tag. 
        #name = headline_i['class'][0].strip() # use the class attribute name as column name.
        value = headline_i.text.strip() # extract text using build in method        
        film = value.split('\n')[2]
        if len(film)> 6:
            film = value.split(' ')[-1]
        year_list.append(film)


len(year_list)

year_list
# Out:
# ['(1994)',
#  '(2008)',
#  '(2010)',
#  '(1999)',
#  '(1994)',
#  '(1994)',
#  '(1999)',
#  '(2001)',
#  '(2003)',
#  '(1972)',
#  '(2012)',
#  '(2002)',
#  '(2014)',
#  '(1995)',
#  '(2012)',
#  '(2000)',
#  '(2005)',
#  '(2012)',
#  '(1991)',
#  '(2009)',
#  '(1977)',
#  '(1998)',
#  '(1993)',
#  '(2006)',
#  '(2006)',
#  '(1980)',
#  '(2009)',
#  '(2013)',
#  '(2000)',
#  '(1999)',
#  '(2010)',
#  '(1974)',
#  '(1999)',
#  '(2003)',
#  '(1997)',
#  '(2014)',
#  '(1998)',
#  '(2005)',
#  '(1985)',
#  '(1994)',
#  '(1991)',
#  '(1990)',
#  '(2008)',
#  '(2003)',
#  '(1995)',
#  '(1995)',
#  '(2003)',
#  '(2008)',
#  '(1983)',
#  '(2009)']

# %%
#Extrating the stars (not working)

stars_list= []

for v in range(1, 2):
    url1 = 'https://www.imdb.com/search/keyword/?ref_=kw_ref_typ&sort=moviemeter%2Casc&mode=detail&page={}&title_type=movie&fbclid=IwAR3AAeVD_whYi1AwPsSGdYsgH8FnupVrBhImRFD__GL3wdHegJwcxrUsfyc'.format(v)
    call = 'Exam, KU{}'.format(v)
    response,callid = connector.get(url1, call)
    html = response.text
    soup = BeautifulSoup(html,'lxml')
    
    for i in range(1,50):
        headline_i = soup.findAll('p', {'class':'test-muted text-small'})[i] # search for the first headline: h1 tag. 
        #name = headline_i['class'][0].strip() # use the class attribute name as column name.
        value = headline_i.text.strip() # extract text using build in method        
        film = value.split('\n')
        stars_list.append(film)

        

stars_list
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-188-d59e706a14ef> in <module>
#      11
#      12     for i in range(1,50):
# ---> 13         headline_i = soup.findAll('p', {'class':'test-muted text-small'})[i] # search for the first headline: h1 tag.
#      14         #name = headline_i['class'][0].strip() # use the class attribute name as column name.
#      15         value = headline_i.text.strip() # extract text using build in method
#
# IndexError: list index out of range

# %%
import re

year_list=[]

for i in range(50):
    headline_i = soup.findAll('h3')[1] # search for the first headline: h1 tag. 
    value = headline_i.text.strip() # extract text using build in method        
    film = value.split('\n')
    #film1 = value.split(' ')[-1]
    year_list.append(film1)

year_list
# Out:
# ['(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)',
#  '(2017)']
