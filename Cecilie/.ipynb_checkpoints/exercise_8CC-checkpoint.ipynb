# %% [markdown]
# > **Note:** In most sessions you will be solving exercises posed in a Jupyter notebook that looks like this one. Because you are cloning a Github repository that only we can push to, you should **NEVER EDIT** any of the files you pull from Github. Instead, what you should do, is either make a new notebook and write your solutions in there, or **make a copy of this notebook and save it somewhere else** on your computer, not inside the `sds` folder that you cloned, so you can write your answers in there. If you edit the notebook you pulled from Github, those edits (possible your solutions to the exercises) may be overwritten and lost the next time you pull from Github. This is important, so don't hesitate to ask if it is unclear.

# %% [markdown]
# ## Use Connector class for accessing the internet
# Even if logging is not important for the below exercises, get in the habit of using this class for connecting to the internet, to practice logging your activity. This will be expected in the final exam.

# %%
import requests,os,time
def ratelimit():
    "A function that handles the rate of your calls."
    time.sleep(1) # sleep one second.

class Connector():
  def __init__(self,logfile,overwrite_log=False,connector_type='requests',session=False,path2selenium='',n_tries = 5,timeout=30):
    """This Class implements a method for reliable connection to the internet and monitoring. 
    It handles simple errors due to connection problems, and logs a range of information for basic quality assessments
    
    Keyword arguments:
    logfile -- path to the logfile
    overwrite_log -- bool, defining if logfile should be cleared (rarely the case). 
    connector_type -- use the 'requests' module or the 'selenium'. Will have different since the selenium webdriver does not have a similar response object when using the get method, and monitoring the behavior cannot be automated in the same way.
    session -- requests.session object. For defining custom headers and proxies.
    path2selenium -- str, sets the path to the geckodriver needed when using selenium.
    n_tries -- int, defines the number of retries the *get* method will try to avoid random connection errors.
    timeout -- int, seconds the get request will wait for the server to respond, again to avoid connection errors.
    """
    
    ## Initialization function defining parameters. 
    self.n_tries = n_tries # For avoiding triviel error e.g. connection errors, this defines how many times it will retry.
    self.timeout = timeout # Defining the maximum time to wait for a server to response.
    ## not implemented here, if you use selenium.
    if connector_type=='selenium':
      assert path2selenium!='', "You need to specify the path to you geckodriver if you want to use Selenium"
      from selenium import webdriver 
      ## HIN download the latest geckodriver here: https://github.com/mozilla/geckodriver/releases

      assert os.path.isfile(path2selenium),'You need to insert a valid path2selenium the path to your geckodriver. You can download the latest geckodriver here: https://github.com/mozilla/geckodriver/releases'
      self.browser = webdriver.Firefox(executable_path=path2selenium) # start the browser with a path to the geckodriver.

    self.connector_type = connector_type # set the connector_type
    
    if session: # set the custom session
      self.session = session
    else:
      self.session = requests.session()
    self.logfilename = logfile # set the logfile path
    ## define header for the logfile
    header = ['id','project','connector_type','t', 'delta_t', 'url', 'redirect_url','response_size', 'response_code','success','error']
    if os.path.isfile(logfile):        
      if overwrite_log==True:
        self.log = open(logfile,'w')
        self.log.write(';'.join(header))
      else:
        self.log = open(logfile,'a')
    else:
      self.log = open(logfile,'w')
      self.log.write(';'.join(header))
    ## load log 
    with open(logfile,'r') as f: # open file
        
      l = f.read().split('\n') # read and split file by newlines.
      ## set id
      if len(l)<=1:
        self.id = 0
      else:
        self.id = int(l[-1][0])+1
            
  def get(self,url,project_name):
    """Method for connector reliably to the internet, with multiple tries and simple error handling, as well as default logging function.
    Input url and the project name for the log (i.e. is it part of mapping the domain, or is it the part of the final stage in the data collection).
    
    Keyword arguments:
    url -- str, url
    project_name -- str, Name used for analyzing the log. Use case could be the 'Mapping of domain','Meta_data_collection','main data collection'. 
    """
     
    project_name = project_name.replace(';','-') # make sure the default csv seperator is not in the project_name.
    if self.connector_type=='requests': # Determine connector method.
      for _ in range(self.n_tries): # for loop defining number of retries with the requests method.
        ratelimit()
        t = time.time()
        try: # error handling 
          response = self.session.get(url,timeout = self.timeout) # make get call

          err = '' # define python error variable as empty assumming success.
          success = True # define success variable
          redirect_url = response.url # log current url, after potential redirects 
          dt = t - time.time() # define delta-time waiting for the server and downloading content.
          size = len(response.text) # define variable for size of html content of the response.
          response_code = response.status_code # log status code.
          ## log...
          call_id = self.id # get current unique identifier for the call
          self.id+=1 # increment call id
          #['id','project_name','connector_type','t', 'delta_t', 'url', 'redirect_url','response_size', 'response_code','success','error']
          row = [call_id,project_name,self.connector_type,t,dt,url,redirect_url,size,response_code,success,err] # define row to be written in the log.
          self.log.write('\n'+';'.join(map(str,row))) # write log.
          return response,call_id # return response and unique identifier.

        except Exception as e: # define error condition
          err = str(e) # python error
          response_code = '' # blank response code 
          success = False # call success = False
          size = 0 # content is empty.
          redirect_url = '' # redirect url empty 
          dt = t - time.time() # define delta t

          ## log...
          call_id = self.id # define unique identifier
          self.id+=1 # increment call_id

          row = [call_id,project_name,self.connector_type,t,dt,url,redirect_url,size,response_code,success,err] # define row
          self.log.write('\n'+';'.join(map(str,row))) # write row to log.
    else:
      t = time.time()
      ratelimit()
      self.browser.get(url) # use selenium get method
      ## log
      call_id = self.id # define unique identifier for the call. 
      self.id+=1 # increment the call_id
      err = '' # blank error message
      success = '' # success blank
      redirect_url = self.browser.current_url # redirect url.
      dt = t - time.time() # get time for get method ... NOTE: not necessarily the complete load time.
      size = len(self.browser.page_source) # get size of content ... NOTE: not necessarily correct, since selenium works in the background, and could still be loading.
      response_code = '' # empty response code.
      row = [call_id,project_name,self.connector_type,t,dt,url,redirect_url,size,response_code,success,err] # define row 
      self.log.write('\n'+';'.join(map(str,row))) # write row to log file.
    # Using selenium it will not return a response object, instead you should call the browser object of the connector.
    ## connector.browser.page_source will give you the html.
      return call_id
logfile = 'my_log8'## name your log file.
connector = Connector(logfile)

# %% [markdown]
# # Exercise Set 8: Introduction to Web Scraping
#
# *Afternoon, August 16, 2018*
#
# In this Exercise Set we shall practice our webscraping skills utiilizing only basic python. We shall cover variations between static and dynamic pages and build.

# %% [markdown]
# ## Exercise Section 8.1: Scraping Jobnet.dk
#
# This exercise you get to practice locating the request that the JavaScript sends to get the job data that it builds the joblistings from. You should use the **>Network Monitor<** tool in your browser.
#
# Furthermore you practice spotting how the pagination is done, without clicking on the next page button, but instead changing a small parameter in the URL.

# %% [markdown]
# > **Ex. 8.1.1:** Hit the joblisting webpage here: https://job.jobnet.dk/CV and locate the request that gets the joblisting data using the the **>Network Monitor<**. *(Hint: Filter by XHR files)
#
# > **Ex. 8.1.2.:** Use the `request` module to collect the first 20 results and unpack the relevant `json` data into a `pandas` DataFrame.
#
# > **Ex. 8.1.3.:** Store the 'TotalResultCount' value for later use.

# %%
# [Answer to Ex. 8.1.1-3 here]
import requests
import json
import pandas as pd

url = 'https://job.jobnet.dk/CV/FindWork/Search'
response, call_id = connector.get(url,'jobnet')
if response.ok:
    d = response.json()
else:
    print('error')
    
df = pd.DataFrame(d['JobPositionPostings'])  
df.head()

n_listings = d['TotalResultCount']
# Out:
# 14772

# %% [markdown]
# > **Ex. 8.1.4:** This exercise is about paging the results. We need to understand the websites pagination scheme.
#
# > Now scroll down the webpage and press the next page button. See how the parameters of the url changes as you turn the pages.
#
# > **Ex. 8.1.5:** Design a`for` loop using the `range` function that changes this paging parameter in the URL. Use the TotalResultCount parameter from before to define the limits of the range function. Store these urls in a container.
#
# >**extra** Change the SortValue parameter from BestMatch to CreationDate, to make the sorting amendable to updating results daily.
#
# *(HINT: See that the parameter is an offset and that this relates to the number of results pr. call made.)*

# %%
# [Answer to Ex. 8.1.4-5 here]

q = 'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=%d'

links = []

for offset in range(0, n_listings+20, 20):
    url = q%offset
    links.append(url)
# Out:
# ['https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=0',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=20',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=40',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=60',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=80',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=100',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=120',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=140',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=160',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=180',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=200',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=220',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=240',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=260',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=280',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=300',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=320',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=340',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=360',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=380',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=400',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=420',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=440',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=460',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=480',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=500',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=520',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=540',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=560',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=580',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=600',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=620',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=640',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=660',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=680',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=700',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=720',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=740',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=760',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=780',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=800',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=820',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=840',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=860',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=880',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=900',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=920',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=940',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=960',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=980',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1000',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1020',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1040',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1060',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1080',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1100',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1120',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1140',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1160',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1180',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1200',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1220',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1240',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1260',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1280',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1300',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1320',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1340',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1360',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1380',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1400',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1420',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1440',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1460',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1480',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1500',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1520',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1540',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1560',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1580',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1600',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1620',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1640',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1660',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1680',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1700',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1720',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1740',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1760',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1780',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1800',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1820',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1840',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1860',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1880',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1900',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1920',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1940',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1960',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=1980',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2000',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2020',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2040',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2060',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2080',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2100',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2120',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2140',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2160',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2180',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2200',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2220',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2240',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2260',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2280',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2300',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2320',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2340',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2360',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2380',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2400',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2420',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2440',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2460',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2480',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2500',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2520',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2540',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2560',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2580',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2600',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2620',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2640',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2660',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2680',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2700',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2720',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2740',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2760',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2780',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2800',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2820',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2840',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2860',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2880',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2900',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2920',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2940',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2960',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=2980',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3000',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3020',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3040',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3060',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3080',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3100',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3120',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3140',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3160',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3180',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3200',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3220',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3240',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3260',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3280',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3300',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3320',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3340',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3360',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3380',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3400',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3420',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3440',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3460',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3480',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3500',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3520',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3540',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3560',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3580',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3600',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3620',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3640',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3660',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3680',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3700',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3720',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3740',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3760',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3780',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3800',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3820',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3840',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3860',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3880',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3900',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3920',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3940',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3960',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=3980',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4000',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4020',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4040',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4060',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4080',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4100',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4120',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4140',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4160',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4180',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4200',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4220',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4240',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4260',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4280',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4300',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4320',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4340',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4360',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4380',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4400',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4420',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4440',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4460',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4480',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4500',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4520',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4540',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4560',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4580',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4600',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4620',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4640',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4660',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4680',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4700',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4720',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4740',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4760',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4780',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4800',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4820',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4840',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4860',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4880',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4900',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4920',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4940',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4960',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=4980',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5000',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5020',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5040',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5060',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5080',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5100',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5120',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5140',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5160',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5180',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5200',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5220',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5240',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5260',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5280',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5300',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5320',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5340',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5360',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5380',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5400',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5420',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5440',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5460',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5480',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5500',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5520',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5540',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5560',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5580',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5600',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5620',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5640',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5660',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5680',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5700',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5720',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5740',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5760',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5780',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5800',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5820',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5840',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5860',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5880',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5900',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5920',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5940',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5960',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=5980',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6000',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6020',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6040',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6060',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6080',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6100',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6120',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6140',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6160',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6180',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6200',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6220',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6240',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6260',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6280',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6300',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6320',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6340',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6360',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6380',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6400',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6420',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6440',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6460',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6480',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6500',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6520',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6540',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6560',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6580',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6600',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6620',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6640',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6660',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6680',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6700',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6720',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6740',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6760',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6780',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6800',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6820',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6840',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6860',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6880',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6900',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6920',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6940',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6960',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=6980',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7000',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7020',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7040',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7060',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7080',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7100',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7120',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7140',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7160',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7180',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7200',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7220',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7240',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7260',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7280',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7300',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7320',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7340',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7360',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7380',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7400',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7420',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7440',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7460',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7480',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7500',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7520',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7540',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7560',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7580',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7600',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7620',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7640',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7660',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7680',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7700',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7720',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7740',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7760',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7780',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7800',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7820',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7840',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7860',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7880',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7900',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7920',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7940',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7960',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=7980',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8000',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8020',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8040',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8060',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8080',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8100',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8120',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8140',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8160',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8180',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8200',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8220',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8240',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8260',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8280',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8300',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8320',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8340',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8360',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8380',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8400',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8420',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8440',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8460',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8480',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8500',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8520',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8540',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8560',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8580',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8600',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8620',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8640',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8660',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8680',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8700',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8720',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8740',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8760',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8780',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8800',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8820',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8840',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8860',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8880',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8900',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8920',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8940',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8960',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=8980',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9000',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9020',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9040',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9060',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9080',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9100',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9120',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9140',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9160',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9180',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9200',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9220',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9240',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9260',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9280',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9300',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9320',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9340',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9360',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9380',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9400',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9420',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9440',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9460',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9480',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9500',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9520',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9540',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9560',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9580',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9600',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9620',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9640',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9660',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9680',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9700',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9720',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9740',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9760',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9780',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9800',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9820',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9840',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9860',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9880',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9900',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9920',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9940',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9960',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=9980',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10000',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10020',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10040',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10060',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10080',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10100',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10120',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10140',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10160',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10180',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10200',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10220',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10240',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10260',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10280',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10300',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10320',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10340',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10360',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10380',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10400',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10420',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10440',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10460',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10480',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10500',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10520',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10540',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10560',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10580',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10600',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10620',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10640',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10660',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10680',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10700',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10720',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10740',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10760',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10780',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10800',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10820',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10840',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10860',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10880',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10900',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10920',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10940',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10960',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=10980',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11000',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11020',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11040',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11060',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11080',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11100',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11120',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11140',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11160',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11180',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11200',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11220',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11240',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11260',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11280',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11300',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11320',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11340',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11360',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11380',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11400',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11420',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11440',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11460',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11480',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11500',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11520',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11540',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11560',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11580',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11600',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11620',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11640',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11660',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11680',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11700',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11720',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11740',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11760',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11780',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11800',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11820',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11840',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11860',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11880',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11900',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11920',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11940',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11960',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=11980',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12000',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12020',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12040',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12060',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12080',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12100',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12120',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12140',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12160',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12180',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12200',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12220',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12240',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12260',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12280',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12300',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12320',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12340',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12360',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12380',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12400',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12420',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12440',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12460',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12480',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12500',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12520',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12540',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12560',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12580',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12600',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12620',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12640',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12660',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12680',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12700',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12720',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12740',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12760',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12780',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12800',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12820',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12840',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12860',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12880',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12900',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12920',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12940',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12960',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=12980',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13000',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13020',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13040',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13060',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13080',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13100',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13120',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13140',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13160',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13180',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13200',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13220',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13240',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13260',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13280',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13300',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13320',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13340',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13360',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13380',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13400',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13420',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13440',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13460',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13480',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13500',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13520',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13540',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13560',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13580',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13600',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13620',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13640',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13660',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13680',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13700',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13720',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13740',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13760',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13780',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13800',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13820',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13840',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13860',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13880',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13900',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13920',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13940',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13960',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=13980',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14000',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14020',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14040',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14060',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14080',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14100',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14120',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14140',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14160',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14180',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14200',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14220',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14240',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14260',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14280',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14300',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14320',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14340',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14360',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14380',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14400',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14420',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14440',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14460',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14480',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14500',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14520',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14540',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14560',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14580',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14600',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14620',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14640',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14660',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14680',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14700',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14720',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14740',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14760',
#  'https://job.jobnet.dk/CV/FindWork/Search?SortValue=CreationDate&Offset=14780']

# %% [markdown]
# > **Ex.8.1.6:** Pick 20 random links using the `random.sample()` function and collect them using the `Connector` class. Also use the `time.sleep()` function to limit the rate of your calls. Make sure to save the links already collected in a `set()` container to avoid having to reload links already collected. ***extra***: monitor the time left to completing the loop by using `tqdm.tqdm()` function.
#
# > **Ex.8.1.7:** Load all the results into a DataFrame.

# %%
# [Answer to Ex. 8.1.6-7 here]

import random
import time

done = set()
data = []

import tqdm
for url in tqdm.tqdm(random.sample(links,20)):
    response,call_id = connector.get(url, 'download_jobposting')
    if response.ok:
        d = response.json()
    else:
        print('error')
    data += d['JobPositionPostings']
    time.sleep(0.5)

df = pd.DataFrame(data)

df.sample(5)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [00:34<00:00,  1.71s/it]
#      AnonymousEmployer  AssignmentStartDate  AutomatchType  Country  \
# 182              False  0001-01-01T00:00:00              0  Danmark
# 195              False  0001-01-01T00:00:00              0  Danmark
# 19               False  0001-01-01T00:00:00              0  Danmark
# 287              False  0001-01-01T00:00:00              0  Danmark
# 361              False  0001-01-01T00:00:00              0  Danmark
#
#                                             DetailsUrl EmploymentType  \
# 182  https://job.jobnet.dk/CV/FindWork/Details/4999991
# 195  https://job.jobnet.dk/CV/FindWork/Details/5013135
# 19   https://job.jobnet.dk/CV/FindWork/Details/5026564
# 287  https://job.jobnet.dk/CV/FindWork/Details/5027147
# 361  https://job.jobnet.dk/CV/FindWork/Details/5030558
#
#      HasLocationValues  HiringOrgCVR             HiringOrgName       ID  ...  \
# 182               True      83136316  SALTEN SMEDE- OG VVS A/S  4999991  ...
# 195               True      29189668           Randers Kommune  5013135  ...
# 19                True      29138060      Universal Robots A/S  5026564  ...
# 287               True      99999999  FDD, depot Frederikshavn  5027147  ...
# 361               True      29190658           Region Sjælland  5030558  ...
#
#      UseWorkPlaceAddressForJoblog  Weight  WorkHours WorkPlaceAbroad  \
# 182                          True     1.0    Fuldtid           False
# 195                          True     1.0     Deltid           False
# 19                           True     1.0    Fuldtid           False
# 287                          True     1.0    Fuldtid           False
# 361                         False     1.0     Deltid           False
#
#             WorkPlaceAddress  WorkPlaceCity WorkPlaceNotStatic  \
# 182           Knudlundvej 17           Them              False
# 195              Møllegade 4      Randers C              False
# 19   C. F. Tietgens Blvd. 40      Odense SØ              False
# 287          Vrangbækvej 109  Frederikshavn              False
# 361            Lykkebækvej 1           Køge              False
#
#     WorkPlaceOtherAddress  WorkPlacePostalCode WorkplaceID
# 182                 False                 8653       24588
# 195                 False                 8900           0
# 19                  False                 5220       99675
# 287                 False                 9900           0
# 361                  True                 4600       61350
#
# [5 rows x 44 columns]

# %% [markdown]
# ## Exercise Section 8.2: Scraping Trustpilot.com
# Now for a slightly more elaborate, yet still simple scraping problem. Here we want to scrape trustpilot for user reviews. This data is very nice since it provides free labeled data (rating) to train a machine learning model to understand positive and negative sentiment.
#
# Here you will practice crawling a website collecting the links to each company review page, and finally locate another behind the scenes JavaScript request that gets the review data in a neat json format.

# %% [markdown]
# > **Ex. 8.2.1:** Visit the https://www.trustpilot.com/ website and locate the categories page.
# From this page you find links to company listings.
#
# > **Ex. 8.2.2:**
# Get the category page using the `requests` module and extract each link to a specific category page from the HTML. This can be done using the basic python `.split()` string method. Make sure only links within the ***/categories/*** section are kept, checking each string using the ```if 'pattern' in string``` condition.
#
# *(Hint: The links are relative. You need to add the domain name)*

# %%
# [Answer to Ex. 8.2.1-2]

# %% [markdown]
# > **Ex. 8.2.3:** Get one of the category section links. Write a function to extract the links to the company review page from the HTML.
#
# > **Ex. 8.2.4:** Figure out how the pagination is done, by following how the url changes when pressing the **next page**-button to obtain more company listings. Write a function that builds links to paging all the company listing results of each category. This includes parsing the number of subpages of each category and changing the correct parameter in the url.
#
# (Hint: Find the maximum number of result pages, right before the next page button and make a loop change the page parameter of the url.)

# %%
#[Answer to Ex.8.2.3-4]

# %% [markdown]
# > **Ex. 8.2.5:** Loop through all categories and build the paging links using the above defined function.
#
# > **Ex. 8.2.6:** Randomly pick one of category listing links you have generated, and get the links to the companies listed using the other function defined.
#
# > **Ex. 8.2.7:** Visit one of these links and inspect the **>Network Monitor<** to locate the request that loads the review data. Use the requests module to retrieve this link and unpack the json results to a pandas DataFrame.

# %%
#[Answer to Ex.8.2.5-7]

# %% [markdown]
# Congratulations on coming this far. By now you are almost - still need to figure out how to page the reviews and to find the company ID in the html -, ready to deploy a scraper collecting all reviews on trustpilot.
# If you wanna see just how valuable such data could be visit the follow blogpost: https://blog.openai.com/unsupervised-sentiment-neuron/
