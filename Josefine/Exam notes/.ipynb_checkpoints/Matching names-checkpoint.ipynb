# %% [markdown]
# # Determinig names of our actors and actresses

# %%
## Standard stuff:
import numpy as np, seaborn as sns, pandas as pd
## For text classification:
import nltk, nltk.sentiment, sklearn
# %matplotlib inline
import random 
from nltk.corpus import names 
import nltk 
import random
import pandas as pd

# %%
df = pd.read_csv('movie.csv')

# %%
from nltk.tokenize import TweetTokenizer 

token = nltk.tokenize.TweetTokenizer()

def preprocessing(string): 
    v1 = string.lower()
    v2 = token.tokenize(v1)
    
    return v2

def preprocessing_full(string): 
    v1 = string.lower()
    v2 = v1[:-2].strip()
    return v2

# %%
#nltk.download('names')
#name = nltk.corpus.names

#name.fileids()

# %%
#female_names = name.words('female.txt')
#male_names = name.words('male.txt')


#female = set([x.lower() for x in female_names])
#male = set([x.lower() for x in male_names])

#test = []
#for i in range(10000): 
#    if (df['female'] ==1 & df['male'] == 1) & (df['Female actor'] == 'Nan') & df['Male actor'] == 1: 
#        v1 = 'M'
#if df['female'] == 0 & df['male'] == 1 & df['Female actor'] == 'Nan' & df['Male actor'] == 1: 
#        v1 = 'M'
#    v1 = df['female'][i] != df['Female actor'][i]
#    test.append(v1)

# %% [markdown]
# # Reading and converting female first names

# %%
with open('all_female.txt') as f:
    actresses = f.read()
    
all_female= [] 
for i in range(0,5127): 
    if i == 0: 
        v1 = actresses.split(',')[i].strip()[2:-1]
        all_female.append(v1)
    else: 
        v2 = actresses.split(',')[i].strip()[1:-1]
        all_female.append(v2)

# %%
female = [x.lower() for x in all_female]

female_set = set(female)
print(len(female_set))
len(female)
# Out:
# 5124
# 5127

# %% [markdown]
# ## Reading and converting full female actress names

# %%
with open('female_name.txt') as f:
    female_full_name = f.read()
    
actresses_fn = [] 
for i in range(0,606): 
    if i == 0: 
        v1 = female_full_name.split(',')[i].strip()[2:-1]
        actresses_fn.append(v1)
    else: 
        v2 = female_full_name.split(',')[i].strip()[1:-1]
        actresses_fn.append(v2)

# %%
actresses = [x.lower() for x in actresses_fn]

actresses_set = set(actresses)
print(len(actresses_set))
len(actresses)
# Out:
# 605
# 606

# %% [markdown]
# # Reading and converting male names

# %%
with open('all_male.txt') as f:
    actors = f.read()
    
all_male= [] 
for i in range(0,3049): 
    if i == 0: 
        v1 = actors.split(',')[i].strip()[2:-1]
        all_male.append(v1)
    else: 
        v2 = actors.split(',')[i].strip()[1:-1]
        all_male.append(v2)

# %%
male = [x.lower() for x in all_male]
male_set = set(male)

# %% [markdown]
# ## Reading and converting full male actors names

# %%
with open('male_name.txt') as f:
    male_full_name = f.read()
    
actors_fn = [] 
for i in range(0,606): 
    if i == 0: 
        v1 = male_full_name.split(',')[i].strip()[2:-1]
        actors_fn.append(v1)
    else: 
        v2 = male_full_name.split(',')[i].strip()[1:-1]
        actors_fn.append(v2)

# %%
actors = [x.lower() for x in actors_fn]

actors_set = set(actors)
print(len(actors_set))
actors.index('tim robbins')
# Out:
# 604
# 40

# %%
data = df['Top Star'].apply(preprocessing)
data1 = df['Top Star'].apply(preprocessing_full)
data1.head()

data1.loc[0]
# Out:
# 'tim robbins'

# %%
def count_dictionary(document, dictonary):
    filtered_doc = [x for x in document if x in dictonary]
    return len(filtered_doc)#, filtered_doc

# %%
#df['female'] = data.apply(count_dictionary, dictonary = female_set)
#df['male'] = data.apply(count_dictionary, dictonary = male_set)
#df['female_2'] =data1.apply(count_dictionary, dictonary = actresses_set)
#df['male_2'] =data1.apply(count_dictionary, dictonary = actors_set)

# LOOKS UP IF NAME IN DF IS ON FULL NAME ACTORS LIST 
male_actor = []
for i in range(10000): 
    if (data1.loc[i] in actors): 
        v1 = 1
        male_actor.append(v1)
    else: 
        v2 = 0
        male_actor.append(v2)
        
df['Male_actor'] = pd.DataFrame(male_actor)

# LOOKS UP IF NAME IN DF IS ON FULL NAME ACTORESS LIST 
female_actor = []
for i in range(10000): 
    if (data1.loc[i] in actresses): 
        v1 = 1
        female_actor.append(v1)
    else: 
        v2 = 0
        female_actor.append(v2)
        
df['Female_actor'] = pd.DataFrame(female_actor)

# %%
df.head(1)
# Out:
#    Unnamed: 0              Title  Year  Genre  Rating    Gross  \
# 0           0  En verden udenfor  1994  Drama     9.3  $28.34M
#
#          Director                                            Summary  \
# 0  Frank Darabont  Two imprisoned men bond over a number of years...
#
#         Top Star            Star 2        Star 3          Star 4  Male_actor  \
# 0  Tim Robbins,   Morgan Freeman,   Bob Gunton,   William Sadler           1
#
#    Female_actor
# 0             0

# %%
# MAKES A COLUMN THAT INDICATES WETHER A GENDER HAS BEEN ASSIGNED 
df['test'] = df.apply(lambda row: row.Female_actor + row.Male_actor, axis=1)
# IF 'test'==0 NO GENDER HAS BEEN ASSIGNED 
df.loc[df.test ==0, 'test'].count()
# Out:
# 5190

# %%
df.head(1)
# Out:
#    Unnamed: 0              Title  Year  Genre  Rating    Gross  \
# 0           0  En verden udenfor  1994  Drama     9.3  $28.34M
#
#          Director                                            Summary  \
# 0  Frank Darabont  Two imprisoned men bond over a number of years...
#
#         Top Star            Star 2        Star 3          Star 4  Male_actor  \
# 0  Tim Robbins,   Morgan Freeman,   Bob Gunton,   William Sadler           1
#
#    Female_actor  test
# 0             0     1

# %%
#SELECTING THE ROWS THAT ARE NOT YET ASSIGNED A GENDER
df_ng = df.loc[(df['test'] == 0)]
df_ng

#ASSIGNS GENDER TO THESE ROWS
df_ng['female'] = data.apply(count_dictionary, dictonary = female_set)
df_ng['male'] = data.apply(count_dictionary, dictonary = male_set)

#GENERATES LISTS THAT INDICATE HOW MANY ROWS HAVE NOT BEEN ASSIGNED GENDER 
#OR HAS BEEN A ASSIGNED MULTIPLE GENDERS
sure_male = df_ng.loc[(df_ng['female']==0) & (df_ng['male']>=1)]
sure_female = df_ng.loc[(df_ng['female']>=1)&(df_ng['male']==0)]
neutral_gender = df_ng.loc[(df_ng['female']>=1)&(df_ng['male']>=1)]
no_gender = df_ng.loc[(df_ng['female']==0)&(df_ng['male']==0)]

print(sure_male['male'].count()) #NUMBER OG ROWS THAT ARE UNIQUELY IDENTIFIED AS MALE
print(sure_female['male'].count()) #NUMBER OG ROWS THAT ARE UNIQUELY IDENTIFIED AS FEMALE
print(neutral_gender['male'].count()) #NUMBER OG ROWS THAT ARE IDENTIFIED AS BOTH MALE AND FEMALE
print(no_gender['male'].count()) #NUMBER OG ROWS WITH NO ASSIGNED GENDER
# Out:
# 2134
# 636
# 1069
# 1351
# /Users/josefinebjornholm/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/josefinebjornholm/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
#DEFINE DATAFRAME WITH ONLY THE OBSERVATIONS THAT WERE IDENTIFYED BY FULL NAME 
df_true = df.drop(df[df.test == 0].index)

len(df_true)
# Out:
# 4810

# %%
import pandas as pd
import matplotlib.pyplot as plt
from cycler import cycler
import numpy as np

#GENERATE DATASET WITH ONLY FEMALES AND YEAR 

#year_male = df_gender.groupby(['Year'])['Male_actor'].size()
year_female = df_true.groupby(['Female_actor', 'Year']).size()#.drop(df_true[df_true.Female_actor == 0].index)
#year_female1 = df.drop(df[df.Female_actor==0].index)
                               #'Rating', 'Gross', 'Director','Summary', /
                               #'Top Star', 'Star 2', 'Star 3', 'Star 4']
male = year_female[0]
female = year_female[1]
f = pd.DataFrame(f)
m = pd.DataFrame(m)

merge = pd.merge(f,m, on = 'Year')
merge.columns = [['female','male']]

data = merge.iloc[:4]
data2 = data.reset_index()

df = data2.drop(data2['Year'], axis = 1)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import pandas as pd

# Data
r = [0,1,2,3,4]
#raw_data = {'PFHxA': [20, 1.5, 7, 10, 5], \
#        'PFHpA': [5, 15, 5, 10, 15], \
#        'PFOA': [2, 15, 18, 5, 10], \
#        'PFNA': [2, 15, 18, 5, 10], \
#        'PFDA': [2, 15, 18, 5, 10], \
#        'PFUnDA': [2, 15, 18, 5, 10], \
#        'PFHxS': [2, 15, 18, 5, 10], \
#        'PFOS': [2, 15, 18, 5, 10]}
#df = pd.DataFrame(raw_data)

# From raw value to percentage
totals = [i+j for i,j in zip(df['female'], 
df['male'])]
female = [i / j * 100 for i,j in zip(df['female'], totals)]
male = [i / j * 100 for i,j in zip(df['male'], totals)]
# plot
barWidth = 0.85
names = ('1980','1981','1982','1983','1984')
# Create PFHxA Bars
plt.bar(r, PFHxA, color='#A20101', edgecolor='white', width=barWidth, 
label="PFHxA")
# Create PFHpA Bars
plt.bar(r, PFHpA, bottom=PFHxA, color='#F44E54', edgecolor='white', 
width=barWidth, label="PFHpA")
# Create PFOA Bars
plt.bar(r, PFOA, bottom=[i+j for i,j in zip(PFHxA, PFHpA)], color='#FF9904', 
edgecolor='white', width=barWidth, label="PFOA")
# Create PFNA Bars
plt.bar(r, PFNA, bottom=[i+j+k for i,j,k in zip(PFHxA, PFHpA, PFOA)], 
color='#FDDB5E', edgecolor='white', width=barWidth, label="PFNA")
# Create PFDA Bars
plt.bar(r, PFDA, bottom=[i+j+k+l for i,j,k,l in zip(PFHxA, PFHpA, PFOA, 
PFNA)], color='#BAF1A1', edgecolor='white', width=barWidth, label="PFDA")
# Create PFUnDA Bars
plt.bar(r, PFUnDA, bottom=[i+j+k+l+m for i,j,k,l,m in zip(PFHxA, PFHpA, 
PFOA, PFNA, PFDA)], color='#76AD3B', edgecolor='white', width=barWidth, 
label="PFUnDA")
# Create PFHxS Bars
plt.bar(r, PFHxS, bottom=[i+j+k+l+m+n for i,j,k,l,m,n in zip(PFHxA, PFHpA, 
PFOA, PFNA, PFDA, PFUnDA)], color='#0A709A', edgecolor='white', 
width=barWidth, label="PFHxS")
# Create PFOS Bars
plt.bar(r, PFOS, bottom=[i+j+k+l+m+n+o for i,j,k,l,m,n,o in zip(PFHxA, 
PFHpA, PFOA, PFNA, PFDA, PFUnDA, PFHxS)], color='#5E3F99', 
edgecolor='white', width=barWidth, label="PFOS")


# Custom x axis
plt.xticks(r, names)
plt.xlabel("Sample ID")

# Custom y axis
plt.ylabel("Mass percentage")

# Add a legend
plt.legend(loc='upper left', bbox_to_anchor=(1,1), ncol=1)

# Show graphic
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-141-30b8dd60543b> in <module>
#      19 totals = [i+j for i,j in zip(df['female'],
#      20 df['male'])]
# ---> 21 female = [i / j * 100 for i,j in zip(df['female'], totals)]
#      22 male = [i / j * 100 for i,j in zip(df['male'], totals)]
#      23 # plot
#
# <ipython-input-141-30b8dd60543b> in <listcomp>(.0)
#      19 totals = [i+j for i,j in zip(df['female'],
#      20 df['male'])]
# ---> 21 female = [i / j * 100 for i,j in zip(df['female'], totals)]
#      22 male = [i / j * 100 for i,j in zip(df['male'], totals)]
#      23 # plot
#
# TypeError: unsupported operand type(s) for /: 'tuple' and 'tuple'

# %%
print(df)
print(d)
# Out:
#    PFHxA  PFHpA  PFOA  PFNA  PFDA  PFUnDA  PFHxS  PFOS
# 0   20.0      5     2     2     2       2      2     2
# 1    1.5     15    15    15    15      15     15    15
# 2    7.0      5    18    18    18      18     18    18
# 3   10.0     10     5     5     5       5      5     5
# 4    5.0     15    10    10    10      10     10    10
#   female male
# 0      8   35
# 1      5   29
# 2      7   34
# 3      7   40

# %%
df_gender
# Out:
#       Unnamed: 0                                      Title  Year  \
# 17            17                            Ondskabens øjne  1991
# 40            40                          Kill Bill: Vol. 1  2003
# 55            55                           The Hunger Games  2012
# 72            72                                    Gravity  2013
# 73            73                        Requiem for a Dream  2000
# 92            92      Den fabelagtige Amélie fra Montmartre  2001
# 93            93                                 Black Swan  2010
# 108          108                          Kill Bill: Vol. 2  2004
# 115          115                Aliens - det endelige opgør  1986
# 120          120                        Million Dollar Baby  2004
# 126          126            The Hunger Games: Catching Fire  2013
# 127          127                              Pans labyrint  2006
# 152          152                                 Prometheus  2012
# 167          167                                    Arrival  2016
# 184          184               Rogue One: A Star Wars Story  2016
# 190          190                               The Notebook  2004
# 191          191                           Manden uden navn  2002
# 203          203                                       Juno  2007
# 221          221                       (500) Days of Summer  2009
# 230          230                            Children of Men  2006
# 233          233                                 Ex Machina  2014
# 255          255                                       Lucy  2014
# 261          261                                  Divergent  2014
# 266          266                                   Twilight  2008
# 270          270                                  Niceville  2011
# 289          289       The Hunger Games: Mockingjay - del 1  2014
# 307          307                                  King Kong  2005
# 322          322                        Alice i Eventyrland  2010
# 330          330  Three Billboards Outside Ebbing, Missouri  2017
# 341          341                             Captain Marvel  2019
# ...          ...                                        ...   ...
# 9613        9613                          Hulebjørnens klan  1986
# 9632        9632                                   Hounddog  2007
# 9648        9648                                Submergence  2017
# 9678        9678                        Jing Ke ci Qin Wang  1998
# 9708        9708                         En kvinde i Berlin  2008
# 9734        9734                           Vores livs ferie  2017
# 9750        9750                     Sarajevo - Håbets sang  2006
# 9752        9752          April and the Extraordinary World  2015
# 9779        9779             The Saddest Music in the World  2003
# 9782        9782                                   Kandisha  2008
# 9785        9785                                    Tadpole  2002
# 9795        9795                                  Séraphine  2008
# 9800        9800                      Hello I Must Be Going  2012
# 9804        9804                           Décalage horaire  2002
# 9805        9805                               Irresistible  2006
# 9809        9809                                      Julia  2008
# 9811        9811                                   Die Wand  2012
# 9820        9820                                      10x10  2018
# 9822        9822                                Kûki ningyô  2009
# 9832        9832                                       Nuts  1987
# 9844        9844                          Bro's Before Ho's  2013
# 9888        9888                                Dagen derpå  1986
# 9916        9916                                    Rupture  2016
# 9940        9940               Sidste udkørsel til Brooklyn  1989
# 9957        9957                      Helligtrekongersaften  1996
# 9963        9963                                  Testament  1983
# 9964        9964                                  Distorted  2018
# 9965        9965                               Sleepwalking  2008
# 9982        9982                                    Requiem  2006
# 9999        9999                                 Mama's Boy  2007
#
#                              Genre  Rating     Gross  \
# 17          Crime, Drama, Thriller     8.6  $130.74M
# 40         Action, Crime, Thriller     8.1   $70.10M
# 55       Action, Adventure, Sci-Fi     7.2  $408.01M
# 72         Drama, Sci-Fi, Thriller     7.7  $274.09M
# 73                           Drama     8.3    $3.64M
# 92                 Comedy, Romance     8.3   $33.23M
# 93                 Drama, Thriller     8.0  $106.95M
# 108        Action, Crime, Thriller     8.0   $66.21M
# 115      Action, Adventure, Sci-Fi     8.4   $85.16M
# 120                   Drama, Sport     8.1  $100.49M
# 126      Action, Adventure, Sci-Fi     7.5  $424.67M
# 127            Drama, Fantasy, War     8.2   $37.63M
# 152     Adventure, Mystery, Sci-Fi     7.0  $126.48M
# 167         Drama, Mystery, Sci-Fi     7.9  $100.55M
# 184      Action, Adventure, Sci-Fi     7.8  $532.18M
# 190                 Drama, Romance     7.8   $81.00M
# 191      Action, Mystery, Thriller     7.9  $121.66M
# 203                  Comedy, Drama     7.4  $143.50M
# 221         Comedy, Drama, Romance     7.7   $32.39M
# 230        Drama, Sci-Fi, Thriller     7.9   $35.55M
# 233         Drama, Mystery, Sci-Fi     7.7   $25.44M
# 255       Action, Sci-Fi, Thriller     6.4  $126.66M
# 261     Action, Adventure, Mystery     6.7  $150.95M
# 266        Drama, Fantasy, Romance     5.2  $191.47M
# 270                          Drama     8.1  $169.71M
# 289      Action, Adventure, Sci-Fi     6.6  $337.14M
# 307       Action, Adventure, Drama     7.2  $218.08M
# 322     Adventure, Family, Fantasy     6.4  $334.19M
# 330                   Crime, Drama     8.2   $54.51M
# 341      Action, Adventure, Sci-Fi     7.0  $426.83M
# ...                            ...     ...       ...
# 9613     Adventure, Drama, Fantasy     5.4    $1.95M
# 9632                  Drama, Music     6.3    $0.13M
# 9648      Drama, Romance, Thriller     5.4       NaN
# 9678       Drama, History, Romance     7.2    $1.33M
# 9708     Biography, Drama, History     7.1    $0.29M
# 9734      Adventure, Comedy, Drama     6.7    $3.23M
# 9750                         Drama     7.2    $0.04M
# 9752  Animation, Adventure, Comedy     7.3    $0.29M
# 9779               Comedy, Musical     7.2    $0.67M
# 9782        Crime, Fantasy, Horror     4.5       NaN
# 9785        Comedy, Drama, Romance     6.1    $2.88M
# 9795              Biography, Drama     7.4    $0.88M
# 9800        Comedy, Drama, Romance     6.2    $0.11M
# 9804               Comedy, Romance     6.1    $0.54M
# 9805      Drama, Mystery, Thriller     5.7       NaN
# 9809        Crime, Drama, Thriller     7.0    $0.00M
# 9811       Drama, Fantasy, Mystery     6.8    $0.04M
# 9820                      Thriller     5.0       NaN
# 9822       Drama, Fantasy, Romance     6.9       NaN
# 9832               Drama, Thriller     6.6   $30.95M
# 9844                        Comedy     6.4       NaN
# 9888       Crime, Mystery, Romance     5.9   $25.15M
# 9916      Horror, Sci-Fi, Thriller     4.8       NaN
# 9940                         Drama     6.8    $1.73M
# 9957        Comedy, Drama, Romance     7.2    $0.55M
# 9963                         Drama     6.9    $2.04M
# 9964        Action, Crime, Mystery     5.2       NaN
# 9965                         Drama     6.1    $0.17M
# 9982                 Drama, Horror     6.9    $0.01M
# 9999                 Comedy, Drama     5.2       NaN
#
#                                        Director  \
# 17                               Jonathan Demme
# 40                            Quentin Tarantino
# 55                                    Gary Ross
# 72                               Alfonso Cuarón
# 73                             Darren Aronofsky
# 92                           Jean-Pierre Jeunet
# 93                             Darren Aronofsky
# 108                           Quentin Tarantino
# 115                               James Cameron
# 120                              Clint Eastwood
# 126                            Francis Lawrence
# 127                          Guillermo del Toro
# 152                                Ridley Scott
# 167                            Denis Villeneuve
# 184                              Gareth Edwards
# 190                             Nick Cassavetes
# 191                                  Doug Liman
# 203                               Jason Reitman
# 221                                   Marc Webb
# 230                              Alfonso Cuarón
# 233                                Alex Garland
# 255                                  Luc Besson
# 261                                 Neil Burger
# 266                         Catherine Hardwicke
# 270                                 Tate Taylor
# 289                            Francis Lawrence
# 307                               Peter Jackson
# 322                                  Tim Burton
# 330                             Martin McDonagh
# 341              ['Anna Boden, ', 'Ryan Fleck']
# ...                                         ...
# 9613                            Michael Chapman
# 9632                          Deborah Kampmeier
# 9648                                Wim Wenders
# 9678                                 Kaige Chen
# 9708                             Max Färberböck
# 9734                                Paolo Virzì
# 9750                             Jasmila Zbanic
# 9752  ['Christian Desmares, ', 'Franck Ekinci']
# 9779                                 Guy Maddin
# 9782                        Jérôme Cohen-Olivar
# 9785                                Gary Winick
# 9795                             Martin Provost
# 9800                                Todd Louiso
# 9804                           Danièle Thompson
# 9805                                 Ann Turner
# 9809                                Erick Zonca
# 9811                             Julian Pölsler
# 9820                                 Suzi Ewing
# 9822                           Hirokazu Koreeda
# 9832                                Martin Ritt
# 9844   ['Steffen Haars, ', 'Flip Van der Kuil']
# 9888                               Sidney Lumet
# 9916                           Steven Shainberg
# 9940                                   Uli Edel
# 9957                                Trevor Nunn
# 9963                              Lynne Littman
# 9964                                Rob W. King
# 9965                                 Bill Maher
# 9982                      Hans-Christian Schmid
# 9999                               Tim Hamilton
#
#                                                 Summary  \
# 17    A young F.B.I. cadet must receive the help of ...
# 40    After awakening from a four-year coma, a forme...
# 55    Katniss Everdeen voluntarily takes her younger...
# 72    Two astronauts work together to survive after ...
# 73    The drug-induced utopias of four Coney Island ...
# 92    Amélie is an innocent and naive girl in Paris ...
# 93    A committed dancer struggles to maintain her s...
# 108   The Bride continues her quest of vengeance aga...
# 115   Ellen Ripley is rescued by a deep salvage team...
# 120   A determined woman works with a hardened boxin...
# 126   Katniss Everdeen and Peeta Mellark become targ...
# 127   In the Falangist Spain of 1944, the bookish yo...
# 152   Following clues to the origin of mankind, a te...
# 167   A linguist works with the military to communic...
# 184   The daughter of an Imperial scientist joins th...
# 190   A poor yet passionate young man falls in love ...
# 191   A man is picked up by a fishing boat, bullet-r...
# 203   Faced with an unplanned pregnancy, an offbeat ...
# 221   An offbeat romantic comedy about a woman who d...
# 230   In 2027, in a chaotic world in which women hav...
# 233   A young programmer is selected to participate ...
# 255   A woman, accidentally caught in a dark deal, t...
# 261   In a world divided by factions based on virtue...
# 266   Bella Swan moves to Forks and encounters Edwar...
# 270   An aspiring author during the civil rights mov...
# 289   Katniss Everdeen is in District 13 after she s...
# 307   A greedy film producer assembles a team of mov...
# 322   Nineteen-year-old Alice returns to the magical...
# 330   A mother personally challenges the local autho...
# 341   Carol Danvers becomes one of the universe's mo...
# ...                                                 ...
# 9613  A young Cro-Magnon woman is raised by Neandert...
# 9632  A drama set in the American South, where a pre...
# 9648  In a room with no windows on the eastern coast...
# 9678  In pre-unified China, the King of Qin sends hi...
# 9708  A woman tries to survive the invasion of Berli...
# 9734  A runaway couple go on an unforgettable journe...
# 9750  A woman and her daughter struggle to make thei...
# 9752  It's 1941 but France is trapped in the ninetee...
# 9779  A musical of sorts set in Winnipeg during the ...
# 9782  Shattered by the loss of her child, Nyla Jayde...
# 9785  Coming-of-age story about a suave 15-year-old ...
# 9795  Based on the life of French painter Séraphine ...
# 9800  Circumstances force a young divorcée to move b...
# 9804  A worn-out businessman and a beautician on the...
# 9805  A wife and mother is consumed by the thought t...
# 9809  A woman tries to extort money, using a young b...
# 9811  A woman inexplicably finds herself cut off fro...
# 9820  A man abducts a flower shop owner and holds he...
# 9822  A life-size blow-up doll develops a soul and f...
# 9832  A high-class call girl accused of murder fight...
# 9844  Two brothers have their friendship put to the ...
# 9888  A washed up, alcoholic actress who is prone to...
# 9916  A single mom tries to break free from a myster...
# 9940  Set in Brooklyn during the 1950s against a bac...
# 9957  Shakespeare's comedy of gender confusion, in w...
# 9963  The life of a suburban American family is scar...
# 9964  A couple moves to an isolated, modern, safe ap...
# 9965  The drama follows a twelve-year-old girl's str...
# 9982  An epileptic girl suffers a breakdown during h...
# 9999  A twenty-nine year-old slacker who lives with ...
#
#                     Top Star                  Star 2                  Star 3  \
# 17            Jodie Foster,        Anthony Hopkins,     Lawrence A. Bonney,
# 40             Uma Thurman,        David Carradine,           Daryl Hannah,
# 55       Jennifer Lawrence,        Josh Hutcherson,         Liam Hemsworth,
# 72          Sandra Bullock,         George Clooney,              Ed Harris,
# 73           Ellen Burstyn,             Jared Leto,      Jennifer Connelly,
# 92           Audrey Tautou,      Mathieu Kassovitz,                  Rufus,
# 93         Natalie Portman,             Mila Kunis,         Vincent Cassel,
# 108            Uma Thurman,        David Carradine,         Michael Madsen,
# 115       Sigourney Weaver,          Michael Biehn,            Carrie Henn,
# 120           Hilary Swank,         Clint Eastwood,         Morgan Freeman,
# 126      Jennifer Lawrence,        Josh Hutcherson,         Liam Hemsworth,
# 127          Ivana Baquero,            Ariadna Gil,            Sergi López,
# 152           Noomi Rapace,   Logan Marshall-Green,     Michael Fassbender,
# 167              Amy Adams,          Jeremy Renner,        Forest Whitaker,
# 184         Felicity Jones,             Diego Luna,             Alan Tudyk,
# 190          Gena Rowlands,           James Garner,         Rachel McAdams,
# 191         Franka Potente,             Matt Damon,           Chris Cooper,
# 203             Ellen Page,           Michael Cera,        Jennifer Garner,
# 221        Zooey Deschanel,   Joseph Gordon-Levitt,         Geoffrey Arend,
# 230         Julianne Moore,             Clive Owen,       Chiwetel Ejiofor,
# 233        Alicia Vikander,       Domhnall Gleeson,            Oscar Isaac,
# 255     Scarlett Johansson,         Morgan Freeman,           Min-sik Choi,
# 261       Shailene Woodley,             Theo James,           Kate Winslet,
# 266        Kristen Stewart,       Robert Pattinson,            Billy Burke,
# 270             Emma Stone,            Viola Davis,        Octavia Spencer,
# 289      Jennifer Lawrence,        Josh Hutcherson,         Liam Hemsworth,
# 307            Naomi Watts,             Jack Black,           Adrien Brody,
# 322         Mia Wasikowska,            Johnny Depp,   Helena Bonham Carter,
# 330      Frances McDormand,        Woody Harrelson,           Sam Rockwell,
# 341            Brie Larson,      Samuel L. Jackson,         Ben Mendelsohn,
# ...                      ...                     ...                     ...
# 9613          Daryl Hannah,            Pamela Reed,            James Remar,
# 9632        Dakota Fanning,            David Morse,           Piper Laurie,
# 9648       Alicia Vikander,            Celyn Jones,        Jannik Schümann,
# 9678               Li Gong,           Fengyi Zhang,               Zhou Sun,
# 9708             Nina Hoss,       Evgeniy Sidikhin,            Irm Hermann,
# 9734          Helen Mirren,      Donald Sutherland,        Christian McKay,
# 9750     Mirjana Karanovic,     Luna Zimic Mijovic,             Leon Lucev,
# 9752      Marion Cotillard,     Marc-André Grondin,      Philippe Katerine,
# 9779   Isabella Rossellini,          Mark McKinney,      Maria de Medeiros,
# 9782           Hiam Abbass,            Amal Ayouch,       Khalid Benchagra,
# 9785      Sigourney Weaver,         Aaron Stanford,              Kate Mara,
# 9795        Yolande Moreau,           Ulrich Tukur,           Anne Bennent,
# 9800       Melanie Lynskey,     Christopher Abbott,          Blythe Danner,
# 9804      Juliette Binoche,              Jean Reno,            Sergi López,
# 9805        Susan Sarandon,              Sam Neill,            Emily Blunt,
# 9809         Tilda Swinton,           Saul Rubinek,      Kate del Castillo,
# 9811        Martina Gedeck,                  Luchs,        Karlheinz Hackl,
# 9820          Kelly Reilly,             Luke Evans,            Noel Clarke,
# 9822             Doona Bae,             Arata Iura,            Itsuji Itao,
# 9832      Barbra Streisand,       Richard Dreyfuss,      Maureen Stapleton,
# 9844          Sylvia Hoeks,          Raymond Thiry,      Flip Van der Kuil,
# 9888            Jane Fonda,           Jeff Bridges,             Raul Julia,
# 9916          Noomi Rapace,        Michael Chiklis,            Kerry Bishé,
# 9940  Jennifer Jason Leigh,           Stephen Lang,             Burt Young,
# 9957  Helena Bonham Carter,       Richard E. Grant,          Imogen Stubbs,
# 9963        Jane Alexander,         William Devane,          Rossie Harris,
# 9964       Christina Ricci,       Brendan Fletcher,      Vicellous Shannon,
# 9965       Charlize Theron,             Nick Stahl,        AnnaSophia Robb,
# 9982         Sandra Hüller,      Burghart Klaußner,           Imogen Kogge,
# 9999          Diane Keaton,              Jon Heder,           Jeff Daniels,
#
#                       Star 4  Male_actor  Female_actor  test  Male  Female
# 17              Kasi Lemmons           0             1     1   NaN     NaN
# 40            Michael Madsen           0             1     1   NaN     NaN
# 55             Stanley Tucci           0             1     1   NaN     NaN
# 72          Orto Ignatiussen           0             1     1   NaN     NaN
# 73             Marlon Wayans           0             1     1   NaN     NaN
# 92          Lorella Cravotta           0             1     1   NaN     NaN
# 93              Winona Ryder           0             1     1   NaN     NaN
# 108             Daryl Hannah           0             1     1   NaN     NaN
# 115              Paul Reiser           0             1     1   NaN     NaN
# 120             Jay Baruchel           0             1     1   NaN     NaN
# 126   Philip Seymour Hoffman           0             1     1   NaN     NaN
# 127            Maribel Verdú           0             1     1   NaN     NaN
# 152          Charlize Theron           0             1     1   NaN     NaN
# 167        Michael Stuhlbarg           0             1     1   NaN     NaN
# 184               Donnie Yen           0             1     1   NaN     NaN
# 190             Ryan Gosling           0             1     1   NaN     NaN
# 191               Clive Owen           0             1     1   NaN     NaN
# 203            Jason Bateman           0             1     1   NaN     NaN
# 221       Chloë Grace Moretz           0             1     1   NaN     NaN
# 230            Michael Caine           0             1     1   NaN     NaN
# 233            Sonoya Mizuno           0             1     1   NaN     NaN
# 255                Amr Waked           0             1     1   NaN     NaN
# 261             Jai Courtney           0             1     1   NaN     NaN
# 266             Sarah Clarke           0             1     1   NaN     NaN
# 270      Bryce Dallas Howard           0             1     1   NaN     NaN
# 289          Woody Harrelson           0             1     1   NaN     NaN
# 307       Thomas Kretschmann           0             1     1   NaN     NaN
# 322            Anne Hathaway           0             1     1   NaN     NaN
# 330       Caleb Landry Jones           0             1     1   NaN     NaN
# 341                 Jude Law           0             1     1   NaN     NaN
# ...                      ...         ...           ...   ...   ...     ...
# 9613        Thomas G. Waites           0             1     1   NaN     NaN
# 9632        Granoldo Frazier           0             1     1   NaN     NaN
# 9648       Jean-Pierre Lorit           0             1     1   NaN     NaN
# 9678               Xiaohe Lü           0             1     1   NaN     NaN
# 9708          Rüdiger Vogler           0             1     1   NaN     NaN
# 9734           Janel Moloney           0             1     1   NaN     NaN
# 9750             Kenan Catic           0             1     1   NaN     NaN
# 9752          Jean Rochefort           0             1     1   NaN     NaN
# 9779               David Fox           0             1     1   NaN     NaN
# 9782            Assaad Bouab           0             1     1   NaN     NaN
# 9785             Robert Iler           0             1     1   NaN     NaN
# 9795         Geneviève Mnich           0             1     1   NaN     NaN
# 9800         John Rubinstein           0             1     1   NaN     NaN
# 9804         Scali Delpeyrat           0             1     1   NaN     NaN
# 9805  Charles 'Bud' Tingwell           0             1     1   NaN     NaN
# 9809             Aidan Gould           0             1     1   NaN     NaN
# 9811         Ulrike Beimpold           0             1     1   NaN     NaN
# 9820          Olivia Chenery           0             1     1   NaN     NaN
# 9822             Joe Odagiri           0             1     1   NaN     NaN
# 9832             Karl Malden           0             1     1   NaN     NaN
# 9844               Huub Smit           0             1     1   NaN     NaN
# 9888          Diane Salinger           0             1     1   NaN     NaN
# 9916          Peter Stormare           0             1     1   NaN     NaN
# 9940            Peter Dobson           0             1     1   NaN     NaN
# 9957       Steven Mackintosh           0             1     1   NaN     NaN
# 9963              Roxana Zal           0             1     1   NaN     NaN
# 9964             John Cusack           0             1     1   NaN     NaN
# 9965     Deborra-Lee Furness           0             1     1   NaN     NaN
# 9982           Anna Blomeier           0             1     1   NaN     NaN
# 9999              Anna Faris           0             1     1   NaN     NaN
#
# [1332 rows x 17 columns]
